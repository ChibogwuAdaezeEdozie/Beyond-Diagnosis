# %% [markdown]
# <a href="https://colab.research.google.com/github/ChibogwuAdaezeEdozie/Beyond-Diagnosis/blob/main/Beyond_diagnosis_Edited_(2%2C99).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Necessary Libraries

# %%
# !pip install umap-learn
# !pip install minisom
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pynndescent>=0.5->umap-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# Requirement already satisfied: minisom in /usr/local/lib/python3.12/dist-packages (2.3.5)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from minisom import MiniSom
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import umap
import warnings

# %% [markdown]
# ## Reading Data

# %%
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_excel("/content/drive/MyDrive/used_PROJECT_DATANEW_1.xlsx")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#    YEAR  AGE SEX       OCCUP  MAR_STA DUR_EPIS P_PSY_HX     P_MED_HX FAM_P_HX  \
# 0  2017   26   F       NURSE    WIDOW      0.5     RAPE     DIABETES       NO
# 1  2016   28   F  UNEMPLOYED  MARRIED       48      NaN          NaN      NaN
# 2  2016   26   M  UNEMPLOYED   SINGLE        1       NO  SHORT-SIGHT       NO
# 3  2016   20   M     STUDENT   SINGLE        2      NaN          NaN      NaN
# 4  2016   34   F  UNEMPLOYED   SINGLE        6      NaN          NaN      NaN
#
#   P_SOC_HX  ... INT_GFK INT_S_A_D INT_CAL INT_PROV JUDGMT  INSIGHT   PSE  \
# 0      YES  ...     NaN       NaN     NaN      NaN    NaN  PARTIAL  GOOD
# 1      NaN  ...     NaN       NaN     NaN      NaN   POOR     POOR  GOOD
# 2       NO  ...     NaN       NaN     NaN      NaN   POOR  PARTIAL  GOOD
# 3      YES  ...     NaN       NaN     NaN      NaN    NaN      NaN  GOOD
# 4      NaN  ...     NaN       NaN     NaN      NaN    NaN     POOR  GOOD
#
#       EEG           DIAGN  CLASS
# 0  NORMAL  PARANOID SCHIZ  SCHIZ
# 1  NORMAL  PARANOID SCHIZ  SCHIZ
# 2  NORMAL  PARANOID SCHIZ  SCHIZ
# 3  NORMAL  PARANOID SCHIZ  SCHIZ
# 4  NORMAL  PARANOID SCHIZ  SCHIZ
#
# [5 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   YEAR        664 non-null    int64
#  1   AGE         664 non-null    int64
#  2   SEX         664 non-null    object
#  3   OCCUP       654 non-null    object
#  4   MAR_STA     659 non-null    object
#  5   DUR_EPIS    655 non-null    object
#  6   P_PSY_HX    642 non-null    object
#  7   P_MED_HX    630 non-null    object
#  8   FAM_P_HX    639 non-null    object
#  9   P_SOC_HX    644 non-null    object
#  10  P_SEX_HX    620 non-null    object
#  11  FOR_HX      637 non-null    object
#  12  PREMOBD_HX  623 non-null    object
#  13  MSE         658 non-null    object
#  14  SPEECH      643 non-null    object
#  15  MOOD        594 non-null    object
#  16  AFFECT      604 non-null    object
#  17  TH_FORM     490 non-null    object
#  18  TH_STRM     476 non-null    object
#  19  TH_CONTENT  464 non-null    object
#  20  TH_POSS     284 non-null    object
#  21  PERCEP      468 non-null    object
#  22  ORIENT      549 non-null    object
#  23  ATTEN       555 non-null    object
#  24  CONC        544 non-null    object
#  25  MEM_IR      509 non-null    object
#  26  MEM_ST      483 non-null    object
#  27  MEM_LT      493 non-null    object
#  28  INT_GFK     367 non-null    object
#  29  INT_S_A_D   339 non-null    object
#  30  INT_CAL     327 non-null    object
#  31  INT_PROV    319 non-null    object
#  32  JUDGMT      574 non-null    object
#  33  INSIGHT     591 non-null    object
#  34  PSE         637 non-null    object
#  35  EEG         645 non-null    object
#  36  DIAGN       415 non-null    object
#  37  CLASS       664 non-null    object
# dtypes: int64(2), object(36)
# memory usage: 197.3+ KB

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# 1. YEAR – Year the data was recorded.
#
#
# 2. AGE – Age of the individual.
#
#
# 3. SEX – Gender of the individual.
#
#
# 4. OCCUP – Occupation.
#
#
# 5. MAR_STA – Marital status.
#
#
# 6. DUR_EPIS – Duration of the episode (likely related to a psychiatric or medical condition).
#
#
# 7. P_PSY_HX – Personal psychiatric history.
#
#
# 8. P_MED_HX – Personal medical history.
#
#
# 9. FAM_P_HX – Family psychiatric history.
#
#
# 10. P_SOC_HX – Personal social history.
#
#
# 11. P_SEX_HX – Personal sexual history.
#
#
# 12. FOR_HX – Forensic history (e.g., legal/criminal background).
#
#
# 13. PREMOBD_HX – Premorbid history (functioning before the illness).
#
#
# 14. MSE – Mental State Examination summary.
#
#
# 15. SPEECH – Observations about speech (e.g., rate, volume).
#
#
# 16. MOOD – Subjective emotional state.
#
#
# 17. AFFECT – Observable emotional expression.
#
#
# 18. TH_FORM – Thought form (e.g., coherence, flow).
#
#
# 19. TH_STRM – Thought stream (speed and quantity of thought).
#
#
# 20. TH_CONTENT – Content of thoughts (e.g., delusions).
#
#
# 21. TH_POSS – Thought possession (e.g., thought insertion).
#
#
# 22. PERCEP – Perception abnormalities (e.g., hallucinations).
#
#
# 23. ORIENT – Orientation to time, place, person.
#
#
# 24. ATTEN – Attention.
#
#
# 25. CONC – Concentration.
#
#
# 26. MEM_IR – Immediate recall memory.
#
#
# 27. MEM_ST – Short-term memory.
#
#
# 28. MEM_LT – Long-term memory.
#
#
# 29. INT_GFK – General fund of knowledge/intelligence.
#
#
# 30. INT_S_A_D – Social awareness and decision-making.
#
#
# 31. INT_CAL – Calculations/intellectual ability.
#
#
# 32. INT_PROV – Proverbs (interpreting abstract ideas).
#
#
# 33. JUDGMT – Judgment.
#
#
# 34. INSIGHT – Insight into one’s condition.
#
#
# 35. PSE – Psychiatric symptom evaluation (possibly checklist-based).
#
#
# 36. EEG – Electroencephalogram results or status.
#
#
# 37. DIAGN – Diagnosis.
#
#
# 38. CLASS – Classification of the diagnosis (e.g., ICD or DSM category).

# %% [markdown]
# ### Checking For Missing values

# %%
data.isnull().sum()
# Out:
# YEAR            0
# AGE             0
# SEX             0
# OCCUP          10
# MAR_STA         5
# DUR_EPIS        9
# P_PSY_HX       22
# P_MED_HX       34
# FAM_P_HX       25
# P_SOC_HX       20
# P_SEX_HX       44
# FOR_HX         27
# PREMOBD_HX     41
# MSE             6
# SPEECH         21
# MOOD           70
# AFFECT         60
# TH_FORM       174
# TH_STRM       188
# TH_CONTENT    200
# TH_POSS       380
# PERCEP        196
# ORIENT        115
# ATTEN         109
# CONC          120
# MEM_IR        155
# MEM_ST        181
# MEM_LT        171
# INT_GFK       297
# INT_S_A_D     325
# INT_CAL       337
# INT_PROV      345
# JUDGMT         90
# INSIGHT        73
# PSE            27
# EEG            19
# DIAGN         249
# CLASS           0
# dtype: int64

# %% [markdown]
# ### Percentage Of Missingness In Data

# %%
# check for percentage of null values per column
data.isnull().sum()/len(data)*100
# Out:
# YEAR           0.000000
# AGE            0.000000
# SEX            0.000000
# OCCUP          1.506024
# MAR_STA        0.753012
# DUR_EPIS       1.355422
# P_PSY_HX       3.313253
# P_MED_HX       5.120482
# FAM_P_HX       3.765060
# P_SOC_HX       3.012048
# P_SEX_HX       6.626506
# FOR_HX         4.066265
# PREMOBD_HX     6.174699
# MSE            0.903614
# SPEECH         3.162651
# MOOD          10.542169
# AFFECT         9.036145
# TH_FORM       26.204819
# TH_STRM       28.313253
# TH_CONTENT    30.120482
# TH_POSS       57.228916
# PERCEP        29.518072
# ORIENT        17.319277
# ATTEN         16.415663
# CONC          18.072289
# MEM_IR        23.343373
# MEM_ST        27.259036
# MEM_LT        25.753012
# INT_GFK       44.728916
# INT_S_A_D     48.945783
# INT_CAL       50.753012
# INT_PROV      51.957831
# JUDGMT        13.554217
# INSIGHT       10.993976
# PSE            4.066265
# EEG            2.861446
# DIAGN         37.500000
# CLASS          0.000000
# dtype: float64

# %% [markdown]
# ### Distribution Of Sex

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

plt.figure(figsize=(10,6))
ax = sns.countplot(data=data, x='SEX', palette='viridis')
plt.title('Distribution of Sex', fontsize=16)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# ### Distribution Of Age

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='AGE', kde=True, bins=30)
plt.title('Distribution of Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### OCCUPATION DISTRIBUTION

# %%
# Define your mapping dictionary
occupation_mapping = {
    'NURSE': 'HEALTHCARE',
    'PHYSIOTHERAPIST': 'HEALTHCARE',
    'TEACHING': 'EDUCATION',
    'TEACHER': 'EDUCATION',
    'SCHOOL TEACHER ': 'EDUCATION',
    'SALESWOMAN': 'SALES',
    'SALESMAN': 'SALES',
    'SALES': 'SALES',
    'MECHANIC': 'TRADES',
    'ELECTRICIAN': 'TRADES',
    'CARPENTER': 'TRADES',
    'BRICKLAYER': 'TRADES',
    'BLACKSMITH': 'TRADES',
    'WELDER': 'TRADES',
    'CAPENTER': 'TRADES', # Correcting typo assumption
    'FURNITURE MAKER': 'TRADES',
    'CLEANER': 'SERVICE/MANUAL LABOR',
    'HOUSEWIFE': 'SERVICE/MANUAL LABOR',
    'CATERING': 'SERVICE/MANUAL LABOR',
    'FACTORY WORKER': 'SERVICE/MANUAL LABOR',
    'ENGINEER': 'TECHNICAL/PROFESSIONAL',
    'ARCHITECT': 'TECHNICAL/PROFESSIONAL',
    'SURVEYOR': 'TECHNICAL/PROFESSIONAL',
    'PRINTING ': 'TECHNICAL/PROFESSIONAL',
    'LAWYER': 'ADMINISTRATION/OFFICE',
    'AUDITOR': 'ADMINISTRATION/OFFICE',
    'MARKETER': 'ADMINISTRATION/OFFICE',
    'AGENT': 'ADMINISTRATION/OFFICE',
    'CIVIL': 'ADMINISTRATION/OFFICE', # Assuming 'CIVIL' refers to Civil Servant
    'PUBLIC SERVANT': 'ADMINISTRATION/OFFICE',
    'GUARD': 'SECURITY/MILITARY',
    'SECURITY': 'SECURITY/MILITARY',
    'POLICE': 'SECURITY/MILITARY',
    'NAVAL OFFICER': 'SECURITY/MILITARY',
    'STUDENT': 'STUDENT/TRAINEE',
    'GRADUATE': 'STUDENT/TRAINEE',
    'APPRENTICE': 'STUDENT/TRAINEE',
    'APPLICANT': 'STUDENT/TRAINEE',
    'UNEMPLOYED': 'UNEMPLOYED',
    'RETIRED': 'RETIRED',
    'TRADER': 'BUSINESS', # Grouping some individual categories into broader ones
    'WRITER': 'OTHER PROFESSIONAL',
    'COBBLER': 'TRADES', # Could also be 'SERVICE/MANUAL LABOR' depending on context
    'TAILOR': 'TRADES',
    'CLERGY': 'OTHER PROFESSIONAL',
    'HAIRDRESSER': 'SERVICE/MANUAL LABOR',
    'CORP MEMBER': 'OTHER',
    'BUSINESS': 'BUSINESS',
    'CRAFTSMAN': 'TRADES',
    'FARMER': 'AGRICULTURE',
    'PROSTITUTE': 'SEX WORKER', # Sensitive category, might need careful handling or exclusion
    'FASHION DESIGNER': 'OTHER PROFESSIONAL',
    'SEA MISTRESS': 'OTHER', # Unclear category, placing in 'OTHER'
}

# Apply the mapping to the 'OCCUP' column
data['OCCUP_GROUPED'] = data['OCCUP'].replace(occupation_mapping)

# You can check the new unique values in the grouped column
print(data['OCCUP_GROUPED'].unique())

# You can also check the value counts of the new grouped column
print(data['OCCUP_GROUPED'].value_counts())
# Out:
# ['HEALTHCARE' 'UNEMPLOYED' 'STUDENT/TRAINEE' 'SERVICE/MANUAL LABOR'
#  'OTHER' 'EDUCATION' nan 'SALES' 'BUSINESS' 'TECHNICAL/PROFESSIONAL'
#  'SECURITY/MILITARY' 'ASSISTANT' 'RETIRED' 'OTHER PROFESSIONAL' 'TRADES'
#  'ADMINISTRATION/OFFICE' 'AGRICULTURE' 'SEX WORKER' 'EMPLOYED ' 'DRIVER']
# OCCUP_GROUPED
# UNEMPLOYED                201
# STUDENT/TRAINEE           135
# BUSINESS                  116
# TRADES                     34
# RETIRED                    30
# SECURITY/MILITARY          26
# EDUCATION                  19
# ADMINISTRATION/OFFICE      17
# TECHNICAL/PROFESSIONAL     14
# SALES                      14
# SERVICE/MANUAL LABOR       13
# HEALTHCARE                  7
# OTHER PROFESSIONAL          6
# AGRICULTURE                 6
# OTHER                       5
# EMPLOYED                    5
# ASSISTANT                   3
# SEX WORKER                  2
# DRIVER                      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 10))
ax = sns.countplot(data=data, y='OCCUP_GROUPED', order=data['OCCUP_GROUPED'].value_counts().index, palette='viridis')
plt.title('Distribution of Occupation', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Occupation', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# ### Distribution Of CLASS AND DIAGNOSIS

# %%
plt.figure(figsize=(12, 10))
ax = sns.countplot(data=data, y='CLASS', order=data['CLASS'].value_counts().index, palette='viridis')
plt.title('Distribution of Class', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Class', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
plt.figure(figsize=(15, 10))
ax = sns.countplot(data=data, y='DIAGN', order=data['DIAGN'].value_counts().index, palette='viridis')
plt.title('Distribution of DIAGNOSIS', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Class', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# ### Distribution Of The Duration Of Episode

# %%
data['DUR_EPIS'] = pd.to_numeric(data['DUR_EPIS'], errors='coerce')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='DUR_EPIS', kde=True)
plt.title('Distribution of Duration Of Episode', fontsize=16)
plt.xlabel('Duration Of Episode', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## CLEANING OF DATA

# %%
history_cols = [
    'P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX'
]

# %%
def clean_whitespace(df):
  """
  Strips leading and trailing whitespace from object type columns in a DataFrame.

  Args:
    df: The input pandas DataFrame.

  Returns:
    A new DataFrame with whitespace stripped from object columns.
  """
  df_cleaned = df.copy()
  for col in df_cleaned.select_dtypes(include='object').columns:
    df_cleaned[col] = df_cleaned[col].str.strip()
  return df_cleaned

data_cleaned = clean_whitespace(data)
data_cleaned.head()
# Out:
#    YEAR  AGE SEX       OCCUP  MAR_STA  DUR_EPIS P_PSY_HX     P_MED_HX  \
# 0  2017   26   F       NURSE    WIDOW       0.5     RAPE     DIABETES
# 1  2016   28   F  UNEMPLOYED  MARRIED      48.0      NaN          NaN
# 2  2016   26   M  UNEMPLOYED   SINGLE       1.0       NO  SHORT-SIGHT
# 3  2016   20   M     STUDENT   SINGLE       2.0      NaN          NaN
# 4  2016   34   F  UNEMPLOYED   SINGLE       6.0      NaN          NaN
#
#   FAM_P_HX P_SOC_HX  ... INT_S_A_D INT_CAL INT_PROV JUDGMT  INSIGHT   PSE  \
# 0       NO      YES  ...       NaN     NaN      NaN    NaN  PARTIAL  GOOD
# 1      NaN      NaN  ...       NaN     NaN      NaN   POOR     POOR  GOOD
# 2       NO       NO  ...       NaN     NaN      NaN   POOR  PARTIAL  GOOD
# 3      NaN      YES  ...       NaN     NaN      NaN    NaN      NaN  GOOD
# 4      NaN      NaN  ...       NaN     NaN      NaN    NaN     POOR  GOOD
#
#       EEG           DIAGN  CLASS    OCCUP_GROUPED
# 0  NORMAL  PARANOID SCHIZ  SCHIZ       HEALTHCARE
# 1  NORMAL  PARANOID SCHIZ  SCHIZ       UNEMPLOYED
# 2  NORMAL  PARANOID SCHIZ  SCHIZ       UNEMPLOYED
# 3  NORMAL  PARANOID SCHIZ  SCHIZ  STUDENT/TRAINEE
# 4  NORMAL  PARANOID SCHIZ  SCHIZ       UNEMPLOYED
#
# [5 rows x 39 columns]

# %%
data_cleaned['INSIGHT'] = data_cleaned['INSIGHT'].replace({
    'G': 'GOOD',
    ' LA': 'LACKING',
    'LA': 'LACKING',
    'LACKIN': 'LACKING'
})

data_cleaned['INSIGHT'] = data_cleaned['INSIGHT'].str.strip()
print(data_cleaned['INSIGHT'].unique())
# Out:
# ['PARTIAL' 'POOR' nan 'PERSISTENT' 'GOOD' 'FAIR' 'LACKING' 'IMPAIRED']

# %%
for col in history_cols:
    data_cleaned[col] = data_cleaned[col].replace('N', 'NO')

for col in history_cols:
    print(f"Unique values in {col} after replacement: {data_cleaned[col].unique()}")
# Out:
# Unique values in P_PSY_HX after replacement: ['RAPE' nan 'NO' 'SUSPISION' 'MENTAL ILLNESS' 'IRRITABILITY' 'GRIEF' 'YES'
#  'NOT KNOWN']
# Unique values in P_MED_HX after replacement: ['DIABETES' nan 'SHORT-SIGHT' 'NO' 'SIEZURE' 'MALARIA' 'HADE' 'SHADE'
#  'BLOOD TRANS' 'ALLEGIES' 'HbSS' 'STROKE' 'HDASP' 'IMMUNE DISORDER'
#  'ASPHYXIA' 'JAUNDICE' 'GLAUCOMA' 'ASTHMA' 'HYPTENSIVE' 'YES' 'HIV']
# Unique values in FAM_P_HX after replacement: ['NO' nan 'YES' 'NOT KNOWN' 'COULD NOT BE ACCESSED']
# Unique values in P_SOC_HX after replacement: ['YES' nan 'NO' 'NO KNOWN']
# Unique values in P_SEX_HX after replacement: ['NORMAL' nan 'MASTURBATE' 'GORNORREA' 'RAPE' 'NOT KNOWN' 'NO' 'SEDATED']

# %%
for col in data_cleaned.columns:
    if data_cleaned[col].dtype == 'object':
        unique_count = data_cleaned[col].nunique()
        print(f"Column '{col}': {unique_count} unique values")
        print("\n" + "="*30 + "\n") # Separator for clarity
# Out:
# Column 'SEX': 2 unique values
#
# ==============================
#
# Column 'OCCUP': 56 unique values
#
# ==============================
#
# Column 'MAR_STA': 8 unique values
#
# ==============================
#
# Column 'P_PSY_HX': 8 unique values
#
# ==============================
#
# Column 'P_MED_HX': 20 unique values
#
# ==============================
#
# Column 'FAM_P_HX': 4 unique values
#
# ==============================
#
# Column 'P_SOC_HX': 3 unique values
#
# ==============================
#
# Column 'P_SEX_HX': 7 unique values
#
# ==============================
#
# Column 'FOR_HX': 4 unique values
#
# ==============================
#
# Column 'PREMOBD_HX': 6 unique values
#
# ==============================
#
# Column 'MSE': 10 unique values
#
# ==============================
#
# Column 'SPEECH': 16 unique values
#
# ==============================
#
# Column 'MOOD': 35 unique values
#
# ==============================
#
# Column 'AFFECT': 23 unique values
#
# ==============================
#
# Column 'TH_FORM': 21 unique values
#
# ==============================
#
# Column 'TH_STRM': 22 unique values
#
# ==============================
#
# Column 'TH_CONTENT': 22 unique values
#
# ==============================
#
# Column 'TH_POSS': 18 unique values
#
# ==============================
#
# Column 'PERCEP': 26 unique values
#
# ==============================
#
# Column 'ORIENT': 8 unique values
#
# ==============================
#
# Column 'ATTEN': 7 unique values
#
# ==============================
#
# Column 'CONC': 9 unique values
#
# ==============================
#
# Column 'MEM_IR': 6 unique values
#
# ==============================
#
# Column 'MEM_ST': 3 unique values
#
# ==============================
#
# Column 'MEM_LT': 5 unique values
#
# ==============================
#
# Column 'INT_GFK': 3 unique values
#
# ==============================
#
# Column 'INT_S_A_D': 3 unique values
#
# ==============================
#
# Column 'INT_CAL': 3 unique values
#
# ==============================
#
# Column 'INT_PROV': 3 unique values
#
# ==============================
#
# Column 'JUDGMT': 5 unique values
#
# ==============================
#
# Column 'INSIGHT': 7 unique values
#
# ==============================
#
# Column 'PSE': 3 unique values
#
# ==============================
#
# Column 'EEG': 2 unique values
#
# ==============================
#
# Column 'DIAGN': 49 unique values
#
# ==============================
#
# Column 'CLASS': 4 unique values
#
# ==============================
#
# Column 'OCCUP_GROUPED': 19 unique values
#
# ==============================

# %%
data_cleaned['MOOD'].unique()
# Out:
# array(['NEUTRAL', 'HAPPY', 'RELAXED', 'FINE', 'OK', nan, 'WORRIED', 'SAD',
#        'EUTHYMIC', 'IRRITABLE', 'INCREASED', 'PERPLEXED', 'SEDATED',
#        'ANGRY', 'RESTLESS', 'hAPPY', "I'M NOT HAPPY", "I'M OK", 'NOTHING',
#        'NOT ACCESSED', "I'M HAPPY", 'COULD NOT BE ASSESSED', 'DEFFERED',
#        "I'M NOT ENJOYING", 'FEEL PEACE', 'I FEEL HAPPY', 'I AM NOT HAPPY',
#        'NORMAL', 'I AM HAPPY', 'LET US BE THANKFUL', 'I AM FINE',
#        'I AM SAD', 'I AM NORMAL', 'NOT HAPPY', 'I AM OKAY', 'I AM OK'],
#       dtype=object)

# %% [markdown]
# ### MOOD Mapping

# %%
mood_mapping = {
    'HAPPY': ['HAPPY', 'hAPPY', "I'M HAPPY", 'I FEEL HAPPY', 'I AM HAPPY'],
    'SAD': ['SAD', 'I AM SAD', "I'M NOT HAPPY", 'I AM NOT HAPPY', 'NOT HAPPY', "I'M NOT ENJOYING"],
    'NEUTRAL': ['NEUTRAL', 'FINE', 'OK', "I'M OK", 'I AM FINE', 'I AM OKAY', 'I AM OK', 'NORMAL', 'I AM NORMAL'],
    'WORRIED': ['WORRIED', 'IRRITABLE', 'ANGRY', 'RESTLESS'],
    'RELAXED': ['RELAXED', 'EUTHYMIC', 'FEEL PEACE'],
    'UNKNOWN': ['NOTHING', 'NOT ACCESSED', 'COULD NOT BE ASSESSED', 'DEFFERED'],
    'OTHER': ['INCREASED', 'PERPLEXED', 'SEDATED', 'LET US BE THANKFUL']
}

# %%
reversed_mapping = {}
for standardized_value, original_values in mood_mapping.items():
    for original_value in original_values:
        reversed_mapping[original_value] = standardized_value

# Apply the reversed mapping to the 'MOOD' column
data_cleaned['MOOD_CLEANED'] = data_cleaned['MOOD'].replace(reversed_mapping)

# Check the unique values in the new cleaned column
print(data_cleaned['MOOD_CLEANED'].unique())

# You can also check the value counts of the new grouped column
print(data_cleaned['MOOD_CLEANED'].value_counts())
# Out:
# ['NEUTRAL' 'HAPPY' 'RELAXED' nan 'WORRIED' 'SAD' 'OTHER' 'UNKNOWN']
# MOOD_CLEANED
# HAPPY      288
# NEUTRAL    152
# SAD        113
# RELAXED     21
# WORRIED      9
# OTHER        6
# UNKNOWN      5
# Name: count, dtype: int64

# %% [markdown]
# ### AFFECT Mapping

# %%
data_cleaned['AFFECT'].unique()
# Out:
# array(['DEPRESSED', 'REACTIVE', 'BLUNT', 'RESTRICTED', 'ABNORMAL',
#        'IRRITABLE', 'FEARFUL', 'CONGRUENT', 'SUSPICIOUS', nan, 'FLAT',
#        'DULL', 'EUTHYMIC', 'CALM', 'WEEPING', 'STERN', 'DYSPHORIC',
#        'IRRETABLE', 'APPHREHENSIVE', 'NORMAL', 'SAD', 'LABILE',
#        'INAPPROPRIATE', 'NAD'], dtype=object)

# %%
affect_mapping = {

}

# %%
data_editted = data_cleaned.dropna()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Insight Vs Judgment

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

plt.figure(figsize=(12, 6))
sns.countplot(data=data_cleaned, x='JUDGMT', hue='INSIGHT', palette='viridis')
plt.title('Distribution of Insight by Judgment', fontsize=16)
plt.xlabel('Judgment', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Insight')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gender Relationship to Pschological History

# %%
history_cols = [
    'P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX'
]

for col in history_cols:
    plt.figure(figsize=(10, 6)) # Adjust figure size as needed
    sns.countplot(data=data_cleaned, x=col, hue='SEX', palette='viridis')
    plt.title(f'Distribution of {col} by Sex', fontsize=16)
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.yticks(fontsize=10)
    plt.legend(title='Sex')
    plt.tight_layout()
    plt.show()

# %%
history_cols = [
    'P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX'
]

for col in history_cols:
    # Group by the history column and SEX, and count the occurrences
    history_sex_counts = data_cleaned.groupby([col, 'SEX']).size().unstack(fill_value=0)

    # Print the table
    print(f"Table for Distribution of {col} by Sex:")
    print(history_sex_counts)
    print("\n" + "="*30 + "\n") # Separator for clarity
# Out:
# Table for Distribution of P_PSY_HX by Sex:
# SEX               F    M
# P_PSY_HX
# GRIEF             3    0
# IRRITABILITY      0    2
# MENTAL ILLNESS   29   51
# NO              190  128
# NOT KNOWN         0    1
# RAPE              3    0
# SUSPISION         3    0
# YES             133   99
#
# ==============================
#
# Table for Distribution of P_MED_HX by Sex:
# SEX                F    M
# P_MED_HX
# ALLEGIES           0    2
# ASPHYXIA           0    3
# ASTHMA             3    0
# BLOOD TRANS        2    0
# DIABETES           5    6
# GLAUCOMA           0    3
# HADE               2    0
# HDASP              5    0
# HIV                1    0
# HYPTENSIVE         5    0
# HbSS               0    7
# IMMUNE DISORDER    3    0
# JAUNDICE           0    3
# MALARIA            2    0
# NO               238  193
# SHADE              5    9
# SHORT-SIGHT        0    3
# SIEZURE            5    0
# STROKE             5    0
# YES               74   46
#
# ==============================
#
# Table for Distribution of FAM_P_HX by Sex:
# SEX                      F    M
# FAM_P_HX
# COULD NOT BE ACCESSED    0    1
# NO                     298  213
# NOT KNOWN                1    1
# YES                     63   62
#
# ==============================
#
# Table for Distribution of P_SOC_HX by Sex:
# SEX         F    M
# P_SOC_HX
# NO        318  197
# NO KNOWN    0    1
# YES        44   84
#
# ==============================
#
# Table for Distribution of P_SEX_HX by Sex:
# SEX           F    M
# P_SEX_HX
# GORNORREA     0    3
# MASTURBATE    0    3
# NO            1    2
# NORMAL      345  260
# NOT KNOWN     0    1
# RAPE          3    1
# SEDATED       0    1
#
# ==============================

# %% [markdown]
# ### MOOD VS AFFECT

# %%
ct = pd.crosstab(data_cleaned['MOOD_CLEANED'], data_cleaned['AFFECT'])
plt.figure(figsize=(15,8))
sns.heatmap(ct, annot=True, cmap='YlGnBu')
plt.title('Mood vs Affect Heatmap')
plt.xlabel('Affect')
plt.ylabel('Mood')
plt.show()

# %% [markdown]
# ### MOOD Vs SPEECH

# %%
ct = pd.crosstab(data['MOOD'], data['SPEECH'])
plt.figure(figsize=(12,10))
sns.heatmap(ct, annot=True, cmap='YlGnBu')
plt.title('Mood vs Speech Heatmap')
plt.xlabel('Speech')
plt.ylabel('Mood')
plt.show()

# %%
cluster1_columns = ['MSE', 'MOOD', 'AFFECT', 'TH_FORM', 'TH_STRM', 'TH_CONTENT', 'PERCEP', 'INSIGHT', 'JUDGMT', 'PSE']
cluster2_columns = ['P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX']

data_cleaned[cluster1_columns].isnull().sum()
# Out:
# MSE             6
# MOOD           70
# AFFECT         60
# TH_FORM       174
# TH_STRM       188
# TH_CONTENT    200
# PERCEP        196
# INSIGHT        73
# JUDGMT         90
# PSE            27
# dtype: int64

# %%
data_cleaned[cluster2_columns].isnull().sum()
# Out:
# P_PSY_HX      22
# P_MED_HX      34
# FAM_P_HX      25
# P_SOC_HX      20
# P_SEX_HX      44
# FOR_HX        27
# PREMOBD_HX    41
# dtype: int64

# %%
data_cleaned.shape
# Out:
# (664, 40)

# %% [markdown]
# ## Dropping And Filling Of Missing Values

# %%
# Check the percentage of missing values for each column again
missing_percentages = data_cleaned.isnull().sum() / len(data_cleaned) * 100
print("Percentage of missing values per column:")
print(missing_percentages)

# Define the threshold for dropping columns
missing_threshold = 40

# Identify columns to drop
columns_to_drop = missing_percentages[missing_percentages > missing_threshold].index.tolist()

print(f"\nColumns to drop (missing more than {missing_threshold}%):")
print(columns_to_drop)

# Drop the identified columns from the DataFrame
data_cleaned_dropped = data_cleaned.drop(columns=columns_to_drop)

print("\nShape of the DataFrame after dropping columns:")
print(data_cleaned_dropped.shape)

# Verify that the columns have been dropped and check remaining missing values
print("\nRemaining missing values after dropping columns:")
print(data_cleaned_dropped.isnull().sum())
# Out:
# Percentage of missing values per column:
# YEAR              0.000000
# AGE               0.000000
# SEX               0.000000
# OCCUP             1.506024
# MAR_STA           0.753012
# DUR_EPIS          1.506024
# P_PSY_HX          3.313253
# P_MED_HX          5.120482
# FAM_P_HX          3.765060
# P_SOC_HX          3.012048
# P_SEX_HX          6.626506
# FOR_HX            4.066265
# PREMOBD_HX        6.174699
# MSE               0.903614
# SPEECH            3.162651
# MOOD             10.542169
# AFFECT            9.036145
# TH_FORM          26.204819
# TH_STRM          28.313253
# TH_CONTENT       30.120482
# TH_POSS          57.228916
# PERCEP           29.518072
# ORIENT           17.319277
# ATTEN            16.415663
# CONC             18.072289
# MEM_IR           23.343373
# MEM_ST           27.259036
# MEM_LT           25.753012
# INT_GFK          44.728916
# INT_S_A_D        48.945783
# INT_CAL          50.753012
# INT_PROV         51.957831
# JUDGMT           13.554217
# INSIGHT          10.993976
# PSE               4.066265
# EEG               2.861446
# DIAGN            37.500000
# CLASS             0.000000
# OCCUP_GROUPED     1.506024
# MOOD_CLEANED     10.542169
# dtype: float64
#
# Columns to drop (missing more than 40%):
# ['TH_POSS', 'INT_GFK', 'INT_S_A_D', 'INT_CAL', 'INT_PROV']
#
# Shape of the DataFrame after dropping columns:
# (664, 35)
#
# Remaining missing values after dropping columns:
# YEAR               0
# AGE                0
# SEX                0
# OCCUP             10
# MAR_STA            5
# DUR_EPIS          10
# P_PSY_HX          22
# P_MED_HX          34
# FAM_P_HX          25
# P_SOC_HX          20
# P_SEX_HX          44
# FOR_HX            27
# PREMOBD_HX        41
# MSE                6
# SPEECH            21
# MOOD              70
# AFFECT            60
# TH_FORM          174
# TH_STRM          188
# TH_CONTENT       200
# PERCEP           196
# ORIENT           115
# ATTEN            109
# CONC             120
# MEM_IR           155
# MEM_ST           181
# MEM_LT           171
# JUDGMT            90
# INSIGHT           73
# PSE               27
# EEG               19
# DIAGN            249
# CLASS              0
# OCCUP_GROUPED     10
# MOOD_CLEANED      70
# dtype: int64

# %% [markdown]
# ### CLASS Distribution By AGE

# %%
data_cleaned_dropped['CLASS'] = data_cleaned_dropped['CLASS'].replace(['SHIZ', 'SHICZ'], 'SCHIZ')

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data_cleaned_dropped, x='CLASS', y='AGE', palette='viridis')
plt.title('Distribution of Age by Class', fontsize=16)
plt.xlabel('Class', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10) # Rotate x-axis labels if they overlap
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Filling Of Missing Values

# %%
from sklearn.impute import KNNImputer

cols_with_missing = data_cleaned_dropped.columns[data_cleaned_dropped.isnull().any()].tolist()

print("Columns with remaining missing values:")
print(cols_with_missing)

categorical_cols_to_impute = [col for col in cols_with_missing if data_cleaned_dropped[col].dtype == 'object']
numerical_cols_to_impute = [col for col in cols_with_missing if data_cleaned_dropped[col].dtype != 'object']

print("\nCategorical columns to impute:", categorical_cols_to_impute)
print("Numerical columns to impute:", numerical_cols_to_impute)

for col in categorical_cols_to_impute:
    mode_val = data_cleaned_dropped[col].mode()[0]
    data_cleaned_dropped[col] = data_cleaned_dropped[col].fillna(mode_val)

# Example of median imputation for numerical columns (if you choose this route for some):
for col in numerical_cols_to_impute:
    median_val = data_cleaned_dropped[col].median()
    data_cleaned_dropped[col] = data_cleaned_dropped[col].fillna(median_val)

# imputer = KNNImputer(n_neighbors=5)
# data_imputed_knn = imputer.fit_transform(data_numerical_encoded)
# data_imputed_knn = pd.DataFrame(data_imputed_knn, columns=data_numerical_encoded.columns)

# print("\nMissing values after KNN Imputation (if applied to numerical data):")
# print(data_imputed_knn.isnull().sum())

print("\nMissing values after chosen imputation methods:")
print(data_cleaned_dropped.isnull().sum())
# Out:
# Columns with remaining missing values:
# ['OCCUP', 'MAR_STA', 'DUR_EPIS', 'P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX', 'MSE', 'SPEECH', 'MOOD', 'AFFECT', 'TH_FORM', 'TH_STRM', 'TH_CONTENT', 'PERCEP', 'ORIENT', 'ATTEN', 'CONC', 'MEM_IR', 'MEM_ST', 'MEM_LT', 'JUDGMT', 'INSIGHT', 'PSE', 'EEG', 'DIAGN', 'OCCUP_GROUPED', 'MOOD_CLEANED']
#
# Categorical columns to impute: ['OCCUP', 'MAR_STA', 'P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX', 'MSE', 'SPEECH', 'MOOD', 'AFFECT', 'TH_FORM', 'TH_STRM', 'TH_CONTENT', 'PERCEP', 'ORIENT', 'ATTEN', 'CONC', 'MEM_IR', 'MEM_ST', 'MEM_LT', 'JUDGMT', 'INSIGHT', 'PSE', 'EEG', 'DIAGN', 'OCCUP_GROUPED', 'MOOD_CLEANED']
# Numerical columns to impute: ['DUR_EPIS']
#
# Missing values after chosen imputation methods:
# YEAR             0
# AGE              0
# SEX              0
# OCCUP            0
# MAR_STA          0
# DUR_EPIS         0
# P_PSY_HX         0
# P_MED_HX         0
# FAM_P_HX         0
# P_SOC_HX         0
# P_SEX_HX         0
# FOR_HX           0
# PREMOBD_HX       0
# MSE              0
# SPEECH           0
# MOOD             0
# AFFECT           0
# TH_FORM          0
# TH_STRM          0
# TH_CONTENT       0
# PERCEP           0
# ORIENT           0
# ATTEN            0
# CONC             0
# MEM_IR           0
# MEM_ST           0
# MEM_LT           0
# JUDGMT           0
# INSIGHT          0
# PSE              0
# EEG              0
# DIAGN            0
# CLASS            0
# OCCUP_GROUPED    0
# MOOD_CLEANED     0
# dtype: int64

# %% [markdown]
# ## Modeling : Unsupervised Learning

# %%
mental_state_cols = ['MSE', 'MOOD_CLEANED', 'AFFECT', 'TH_FORM', 'TH_STRM', 'TH_CONTENT', 'PERCEP', 'INSIGHT', 'JUDGMT', 'PSE']
history_cols = ['P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX']


mental_state_cols = [col for col in mental_state_cols if col in data_cleaned_dropped.columns]
history_cols = [col for col in history_cols if col in data_cleaned_dropped.columns]

print("Mental State Columns for Clustering:", mental_state_cols)
print("History Columns for Clustering:", history_cols)

# --- Preprocessing Function ---
def preprocess_for_clustering(df, columns_to_process):
    """
    Handles missing values, encodes categorical, and scales numerical data
    for a given set of columns.
    """
    df_subset = df[columns_to_process].copy()

    # Identify categorical and numerical columns within the subset
    categorical_subset_cols = [col for col in columns_to_process if df_subset[col].dtype == 'object']
    numerical_subset_cols = [col for col in columns_to_process if df_subset[col].dtype != 'object']

    for col in categorical_subset_cols:
        if df_subset[col].isnull().any():
            mode_val = df_subset[col].mode()[0]
            df_subset[col] = df_subset[col].fillna(mode_val)

    for col in numerical_subset_cols:
        if df_subset[col].isnull().any():
            median_val = df_subset[col].median()
            df_subset[col] = df_subset[col].fillna(median_val)

    # Check if missing values are handled
    if df_subset.isnull().sum().sum() > 0:
        print(f"Warning: Missing values still exist after simple imputation in {columns_to_process}:")
        print(df_subset.isnull().sum())

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numerical_subset_cols),
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_subset_cols)
        ],
        remainder='passthrough'
    )

    # Fit and transform the data
    data_processed = preprocessor.fit_transform(df_subset)

    ohe_feature_names = list(preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_subset_cols))
    all_feature_names = numerical_subset_cols + ohe_feature_names

    return data_processed, all_feature_names, df_subset.index
# Out:
# Mental State Columns for Clustering: ['MSE', 'MOOD_CLEANED', 'AFFECT', 'TH_FORM', 'TH_STRM', 'TH_CONTENT', 'PERCEP', 'INSIGHT', 'JUDGMT', 'PSE']
# History Columns for Clustering: ['P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX']

# %% [markdown]
# ### Mental State Modeling

# %%
# --- Process and Cluster Mental State Data ---
print("\n--- Processing and Clustering Mental State Data ---")
mental_state_processed, mental_state_feature_names, mental_state_indices = preprocess_for_clustering(data_cleaned_dropped, mental_state_cols)


# Determine optimal number of clusters for Mental State using the Elbow Method
inertia = []
silhouette_scores = []
k_range = range(2, 101)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10) # Add n_init
    kmeans.fit(mental_state_processed)
    inertia.append(kmeans.inertia_)
    score = silhouette_score(mental_state_processed, kmeans.labels_)
    silhouette_scores.append(score)
    print(f"Mental State: K={k}, Silhouette Score={score:.4f}")


# Plot Elbow Method
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Mental State: Elbow Method for Optimal K')

# Plot Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Mental State: Silhouette Scores for Optimal K')
plt.tight_layout()
plt.show()


optimal_k_mental = 4

kmeans_mental = KMeans(n_clusters=optimal_k_mental, random_state=42, n_init=10)
mental_state_clusters = kmeans_mental.fit_predict(mental_state_processed)


data_cleaned_dropped['Mental_State_Cluster'] = pd.Series(mental_state_clusters, index=mental_state_indices)

print(f"\n--- Analysis of Mental State Clusters ({optimal_k_mental} clusters) ---")
mental_state_analysis = data_cleaned_dropped.groupby('Mental_State_Cluster')[mental_state_cols].agg(lambda x: x.mode()[0] if x.dtype == 'object' else x.median()) # Use median for numerical, mode for categorical
mental_state_analysis
# Out:
# --- Processing and Clustering Mental State Data ---
# Mental State: K=2, Silhouette Score=0.1768
# Mental State: K=3, Silhouette Score=0.1496
# Mental State: K=4, Silhouette Score=0.1699
# Mental State: K=5, Silhouette Score=0.1475
# Mental State: K=6, Silhouette Score=0.1472
# Mental State: K=7, Silhouette Score=0.1311
# Mental State: K=8, Silhouette Score=0.1325
# Mental State: K=9, Silhouette Score=0.1229
# Mental State: K=10, Silhouette Score=0.1222
# Mental State: K=11, Silhouette Score=0.1214
# Mental State: K=12, Silhouette Score=0.1173
# Mental State: K=13, Silhouette Score=0.1374
# Mental State: K=14, Silhouette Score=0.1268
# Mental State: K=15, Silhouette Score=0.1290
# Mental State: K=16, Silhouette Score=0.1238
# Mental State: K=17, Silhouette Score=0.1311
# Mental State: K=18, Silhouette Score=0.1359
# Mental State: K=19, Silhouette Score=0.1281
# Mental State: K=20, Silhouette Score=0.1235
# Mental State: K=21, Silhouette Score=0.1271
# Mental State: K=22, Silhouette Score=0.1267
# Mental State: K=23, Silhouette Score=0.1251
# Mental State: K=24, Silhouette Score=0.1302
# Mental State: K=25, Silhouette Score=0.1469
# Mental State: K=26, Silhouette Score=0.1443
# Mental State: K=27, Silhouette Score=0.1532
# Mental State: K=28, Silhouette Score=0.1464
# Mental State: K=29, Silhouette Score=0.1394
# Mental State: K=30, Silhouette Score=0.1379
# Mental State: K=31, Silhouette Score=0.1516
# Mental State: K=32, Silhouette Score=0.1456
# Mental State: K=33, Silhouette Score=0.1478
# Mental State: K=34, Silhouette Score=0.1549
# Mental State: K=35, Silhouette Score=0.1613
# Mental State: K=36, Silhouette Score=0.1601
# Mental State: K=37, Silhouette Score=0.1654
# Mental State: K=38, Silhouette Score=0.1602
# Mental State: K=39, Silhouette Score=0.1608
# Mental State: K=40, Silhouette Score=0.1522
# Mental State: K=41, Silhouette Score=0.1655
# Mental State: K=42, Silhouette Score=0.1700
# Mental State: K=43, Silhouette Score=0.1706
# Mental State: K=44, Silhouette Score=0.1753
# Mental State: K=45, Silhouette Score=0.1855
# Mental State: K=46, Silhouette Score=0.1721
# Mental State: K=47, Silhouette Score=0.1795
# Mental State: K=48, Silhouette Score=0.1816
# Mental State: K=49, Silhouette Score=0.1800
# Mental State: K=50, Silhouette Score=0.1865
# Mental State: K=51, Silhouette Score=0.1937
# Mental State: K=52, Silhouette Score=0.1800
# Mental State: K=53, Silhouette Score=0.1947
# Mental State: K=54, Silhouette Score=0.1904
# Mental State: K=55, Silhouette Score=0.1958
# Mental State: K=56, Silhouette Score=0.2006
# Mental State: K=57, Silhouette Score=0.1990
# Mental State: K=58, Silhouette Score=0.1998
# Mental State: K=59, Silhouette Score=0.1932
# Mental State: K=60, Silhouette Score=0.1956
# Mental State: K=61, Silhouette Score=0.2002
# Mental State: K=62, Silhouette Score=0.2051
# Mental State: K=63, Silhouette Score=0.2199
# Mental State: K=64, Silhouette Score=0.2185
# Mental State: K=65, Silhouette Score=0.2105
# Mental State: K=66, Silhouette Score=0.2255
# Mental State: K=67, Silhouette Score=0.2254
# Mental State: K=68, Silhouette Score=0.2285
# Mental State: K=69, Silhouette Score=0.2264
# Mental State: K=70, Silhouette Score=0.2266
# Mental State: K=71, Silhouette Score=0.2289
# Mental State: K=72, Silhouette Score=0.2211
# Mental State: K=73, Silhouette Score=0.2345
# Mental State: K=74, Silhouette Score=0.2430
# Mental State: K=75, Silhouette Score=0.2347
# Mental State: K=76, Silhouette Score=0.2502
# Mental State: K=77, Silhouette Score=0.2392
# Mental State: K=78, Silhouette Score=0.2331
# Mental State: K=79, Silhouette Score=0.2473
# Mental State: K=80, Silhouette Score=0.2370
# Mental State: K=81, Silhouette Score=0.2381
# Mental State: K=82, Silhouette Score=0.2403
# Mental State: K=83, Silhouette Score=0.2484
# Mental State: K=84, Silhouette Score=0.2567
# Mental State: K=85, Silhouette Score=0.2561
# Mental State: K=86, Silhouette Score=0.2489
# Mental State: K=87, Silhouette Score=0.2631
# Mental State: K=88, Silhouette Score=0.2601
# Mental State: K=89, Silhouette Score=0.2548
# Mental State: K=90, Silhouette Score=0.2699
# Mental State: K=91, Silhouette Score=0.2631
# Mental State: K=92, Silhouette Score=0.2573
# Mental State: K=93, Silhouette Score=0.2587
# Mental State: K=94, Silhouette Score=0.2640
# Mental State: K=95, Silhouette Score=0.2725
# Mental State: K=96, Silhouette Score=0.2646
# Mental State: K=97, Silhouette Score=0.2687
# Mental State: K=98, Silhouette Score=0.2827
# Mental State: K=99, Silhouette Score=0.2726
# Mental State: K=100, Silhouette Score=0.2762
# --- Analysis of Mental State Clusters (4 clusters) ---
#                         MSE MOOD_CLEANED    AFFECT  TH_FORM   TH_STRM  \
# Mental_State_Cluster
# 0                     KEMPT        HAPPY  REACTIVE  LOGICAL    NORMAL
# 1                     KEMPT        HAPPY      DULL   NORMAL    NORMAL
# 2                     KEMPT        HAPPY  REACTIVE  LOGICAL    NORMAL
# 3                     KEMPT        HAPPY       SAD     POOR  DELUSION
#
#                                 TH_CONTENT                  PERCEP INSIGHT  \
# Mental_State_Cluster
# 0                     PERSECUTORY DELUSION  AUDITORY HALLUCINATION    POOR
# 1                                 DELUSION                AUDITORY    GOOD
# 2                     PERSECUTORY DELUSION  AUDITORY HALLUCINATION    GOOD
# 3                                   NORMAL                AUDITORY    POOR
#
#                      JUDGMT     PSE
# Mental_State_Cluster
# 0                      POOR  NORMAL
# 1                      POOR    GOOD
# 2                      GOOD  NORMAL
# 3                      POOR  NORMAL

# %%
# % of symptom
mental_state_df = data_cleaned_dropped[mental_state_cols + ['Mental_State_Cluster']].copy()

# Convert categorical symptoms to binary 0/1
def encode_symptom(x, col):
    if col == 'MOOD_CLEANED':
        return 1 if x == 'SAD' else 0
    elif col == 'AFFECT':
        return 1 if x == 'DULL' else 0
    elif col in ['TH_FORM', 'TH_STRM']:
        return 1 if x == 'POOR' else 0
    elif col == 'TH_CONTENT':
        return 1 if x in ['DELUSION', 'PERSECUTORY DELUSION'] else 0
    elif col == 'PERCEP':
        return 1 if x == 'AUDITORY HALLUCINATION' else 0
    elif col == 'INSIGHT':
        return 1 if x == 'POOR' else 0
    elif col == 'JUDGMT':
        return 1 if x == 'POOR' else 0
    elif col == 'PSE':
        return 1 if x == 'ABNORMAL' else 0
    else:
        return 0

for col in mental_state_cols:
    mental_state_df[col] = mental_state_df[col].apply(lambda x: encode_symptom(x, col))

# Compute percentage per cluster
cluster_percentages = mental_state_df.groupby('Mental_State_Cluster')[mental_state_cols].mean() * 100
cluster_percentages = cluster_percentages.round(1)

# Plot grouped bar chart
cluster_percentages.plot(kind='bar', figsize=(12,6))
plt.ylabel('Percentage of Patients')
plt.xlabel('Cluster')
plt.title('Mental State Symptom Endorsement Across Clusters')
plt.xticks(rotation=0)
plt.legend(title='Symptom', bbox_to_anchor=(1.05,1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### History Modeling

# %%
# --- Process and Cluster History Data ---
print("\n--- Processing and Clustering History Data ---")
history_processed, history_feature_names, history_indices = preprocess_for_clustering(data_cleaned_dropped, history_cols)


# Determine optimal number of clusters for History using the Elbow Method
inertia = []
silhouette_scores = []
k_range = range(2, 101)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(history_processed)
    inertia.append(kmeans.inertia_)
    score = silhouette_score(history_processed, kmeans.labels_)
    silhouette_scores.append(score)
    print(f"History: K={k}, Silhouette Score={score:.4f}")


# Plot Elbow Method
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('History: Elbow Method for Optimal K')

# Plot Silhouette Scores
plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('History: Silhouette Scores for Optimal K')
plt.tight_layout()
plt.show()



optimal_k_history = 4

kmeans_history = KMeans(n_clusters=optimal_k_history, random_state=42, n_init=10) # Add n_init
history_clusters = kmeans_history.fit_predict(history_processed)

# Add cluster labels back to the original data_cleaned_dropped DataFrame
data_cleaned_dropped['History_Cluster'] = pd.Series(history_clusters, index=history_indices)

print(f"\n--- Analysis of History Clusters ({optimal_k_history} clusters) ---")
history_analysis = data_cleaned_dropped.groupby('History_Cluster')[history_cols].agg(lambda x: x.mode()[0] if x.dtype == 'object' else x.median())
print(history_analysis)
# Out:
# --- Processing and Clustering History Data ---
# History: K=2, Silhouette Score=0.2332
# History: K=3, Silhouette Score=0.2674
# History: K=4, Silhouette Score=0.2811
# History: K=5, Silhouette Score=0.3303
# History: K=6, Silhouette Score=0.3602
# History: K=7, Silhouette Score=0.3635
# History: K=8, Silhouette Score=0.3862
# History: K=9, Silhouette Score=0.4262
# History: K=10, Silhouette Score=0.4547
# History: K=11, Silhouette Score=0.4735
# History: K=12, Silhouette Score=0.4702
# History: K=13, Silhouette Score=0.5018
# History: K=14, Silhouette Score=0.5429
# History: K=15, Silhouette Score=0.5387
# History: K=16, Silhouette Score=0.5472
# History: K=17, Silhouette Score=0.5795
# History: K=18, Silhouette Score=0.5882
# History: K=19, Silhouette Score=0.6113
# History: K=20, Silhouette Score=0.6174
# History: K=21, Silhouette Score=0.6391
# History: K=22, Silhouette Score=0.6440
# History: K=23, Silhouette Score=0.6541
# History: K=24, Silhouette Score=0.6743
# History: K=25, Silhouette Score=0.6834
# History: K=26, Silhouette Score=0.6908
# History: K=27, Silhouette Score=0.6929
# History: K=28, Silhouette Score=0.7120
# History: K=29, Silhouette Score=0.7282
# History: K=30, Silhouette Score=0.7270
# History: K=31, Silhouette Score=0.7368
# History: K=32, Silhouette Score=0.7369
# History: K=33, Silhouette Score=0.7589
# History: K=34, Silhouette Score=0.7454
# History: K=35, Silhouette Score=0.7586
# History: K=36, Silhouette Score=0.7704
# History: K=37, Silhouette Score=0.7741
# History: K=38, Silhouette Score=0.7848
# History: K=39, Silhouette Score=0.7817
# History: K=40, Silhouette Score=0.7926
# History: K=41, Silhouette Score=0.7903
# History: K=42, Silhouette Score=0.7946
# History: K=43, Silhouette Score=0.8082
# History: K=44, Silhouette Score=0.8097
# History: K=45, Silhouette Score=0.8172
# History: K=46, Silhouette Score=0.8237
# History: K=47, Silhouette Score=0.8270
# History: K=48, Silhouette Score=0.8327
# History: K=49, Silhouette Score=0.8266
# History: K=50, Silhouette Score=0.8453
# History: K=51, Silhouette Score=0.8498
# History: K=52, Silhouette Score=0.8584
# History: K=53, Silhouette Score=0.8634
# History: K=54, Silhouette Score=0.8631
# History: K=55, Silhouette Score=0.8721
# History: K=56, Silhouette Score=0.8736
# History: K=57, Silhouette Score=0.8784
# History: K=58, Silhouette Score=0.8843
# History: K=59, Silhouette Score=0.8875
# History: K=60, Silhouette Score=0.8918
# History: K=61, Silhouette Score=0.8959
# History: K=62, Silhouette Score=0.8998
# History: K=63, Silhouette Score=0.9042
# History: K=64, Silhouette Score=0.9077
# History: K=65, Silhouette Score=0.9122
# History: K=66, Silhouette Score=0.9168
# History: K=67, Silhouette Score=0.9212
# History: K=68, Silhouette Score=0.9268
# History: K=69, Silhouette Score=0.9305
# History: K=70, Silhouette Score=0.9325
# History: K=71, Silhouette Score=0.9371
# History: K=72, Silhouette Score=0.9381
# History: K=73, Silhouette Score=0.9377
# History: K=74, Silhouette Score=0.9391
# History: K=75, Silhouette Score=0.9436
# History: K=76, Silhouette Score=0.9418
# History: K=77, Silhouette Score=0.9442
# History: K=78, Silhouette Score=0.9451
# History: K=79, Silhouette Score=0.9475
# History: K=80, Silhouette Score=0.9494
# History: K=81, Silhouette Score=0.9501
# History: K=82, Silhouette Score=0.9515
# History: K=83, Silhouette Score=0.9520
# History: K=84, Silhouette Score=0.9551
# History: K=85, Silhouette Score=0.9546
# History: K=86, Silhouette Score=0.9546
# History: K=87, Silhouette Score=0.9553
# History: K=88, Silhouette Score=0.9587
# History: K=89, Silhouette Score=0.9583
# History: K=90, Silhouette Score=0.9598
# History: K=91, Silhouette Score=0.9628
# History: K=92, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (93). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=93, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (94). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=94, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (95). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=95, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=96, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (97). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=97, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (98). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=98, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (99). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=99, Silhouette Score=0.9623
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (92) found smaller than n_clusters (100). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# History: K=100, Silhouette Score=0.9623
# --- Analysis of History Clusters (4 clusters) ---
#                 P_PSY_HX P_MED_HX FAM_P_HX P_SOC_HX P_SEX_HX FOR_HX PREMOBD_HX
# History_Cluster
# 0                     NO       NO       NO      YES   NORMAL     NO     NORMAL
# 1                    YES       NO       NO       NO   NORMAL     NO     NORMAL
# 2                     NO       NO       NO       NO   NORMAL     NO     NORMAL
# 3                    YES      YES      YES       NO   NORMAL     NO     NORMAL

# %%
# Copy full dataset
history_cols = ['P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX']
history_df = data_cleaned_dropped[history_cols + ['History_Cluster']].copy()

# Convert categorical variables to binary (0 = absence, 1 = presence)
def encode_history(x, col):
    if col in ['P_PSY_HX', 'P_MED_HX', 'FAM_P_HX', 'P_SOC_HX', 'P_SEX_HX', 'FOR_HX', 'PREMOBD_HX']:
        return 1 if x == 'YES' else 0
    else:
        return 0

for col in history_cols:
    history_df[col] = history_df[col].apply(lambda x: encode_history(x, col))

# Compute percentage per cluster
cluster_percentages_history = history_df.groupby('History_Cluster')[history_cols].mean() * 100
cluster_percentages_history = cluster_percentages_history.round(1)

# Plot grouped bar chart
cluster_percentages_history.plot(kind='bar', figsize=(12,6))
plt.ylabel('Percentage of Patients')
plt.xlabel('Cluster')
plt.title('Historical Risk Factor Endorsement Across Clusters')
plt.xticks(rotation=0)
plt.legend(title='Risk Factor', bbox_to_anchor=(1.05,1))
plt.tight_layout()
plt.show()

# %%
# combine ari and mni
metrics_df = pd.DataFrame({
    'Cluster_Type': ['Mental State', 'History'],
    'ARI': [0.9944, 0.4490],
    'NMI': [0.9912, 0.5465]
})

# Plot grouped bar chart
metrics_df.set_index('Cluster_Type').plot(kind='bar', figsize=(8,5))
plt.ylabel('Stability Metric')
plt.title('Cluster Stability Metrics (ARI & NMI)')
plt.ylim(0,1)
plt.xticks(rotation=0)
plt.legend(title='Metric')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cluster Stability Analysis

# %%
# Evaluate clustering stability for Mental State Clusters

# Re-preprocess mental state features
mental_state_processed, mental_feature_names, mental_indices = preprocess_for_clustering(
    data_cleaned_dropped, mental_state_cols
)

# Extract true labels
true_labels_mental = data_cleaned_dropped.loc[mental_indices, 'Mental_State_Cluster'].values

# Define evaluation function (already defined previously)
def evaluate_stability(X, true_labels, domain_name, n_clusters=4, n_runs=500):
    from sklearn.cluster import KMeans
    from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns

    ari_scores = []
    nmi_scores = []
    seeds = range(10, 10 + n_runs)

    for seed in seeds:
        km = KMeans(n_clusters=n_clusters, random_state=seed, n_init=10)
        new_labels = km.fit_predict(X)

        ari = adjusted_rand_score(true_labels, new_labels)
        nmi = normalized_mutual_info_score(true_labels, new_labels)

        ari_scores.append(ari)
        nmi_scores.append(nmi)

        print(f"{domain_name} - Seed={seed} | ARI={ari:.4f}, NMI={nmi:.4f}")

    print(f"\n--- {domain_name} Cluster Stability Summary ---")
    print(f"Mean ARI: {np.mean(ari_scores):.4f} ± {np.std(ari_scores):.4f}")
    print(f"Mean NMI: {np.mean(nmi_scores):.4f} ± {np.std(nmi_scores):.4f}")

    # Plot stability metrics
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    sns.lineplot(x=list(seeds), y=ari_scores, marker='o')
    plt.title(f'{domain_name}: ARI Scores')
    plt.xlabel('Random Seed')
    plt.ylabel('ARI')

    plt.subplot(1, 2, 2)
    sns.lineplot(x=list(seeds), y=nmi_scores, marker='o', color='green')
    plt.title(f'{domain_name}: NMI Scores')
    plt.xlabel('Random Seed')
    plt.ylabel('NMI')

    plt.tight_layout()
    plt.show()

# Run for Mental State
evaluate_stability(mental_state_processed, true_labels_mental, domain_name="Mental State")
# Out:
# Mental State - Seed=10 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=11 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=12 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=13 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=14 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=15 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=16 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=17 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=18 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=19 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=20 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=21 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=22 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=23 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=24 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=25 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=26 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=27 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=28 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=29 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=30 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=31 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=32 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=33 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=34 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=35 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=36 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=37 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=38 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=39 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=40 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=41 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=42 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=43 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=44 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=45 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=46 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=47 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=48 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=49 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=50 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=51 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=52 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=53 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=54 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=55 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=56 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=57 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=58 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=59 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=60 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=61 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=62 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=63 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=64 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=65 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=66 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=67 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=68 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=69 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=70 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=71 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=72 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=73 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=74 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=75 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=76 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=77 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=78 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=79 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=80 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=81 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=82 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=83 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=84 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=85 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=86 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=87 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=88 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=89 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=90 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=91 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=92 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=93 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=94 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=95 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=96 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=97 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=98 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=99 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=100 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=101 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=102 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=103 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=104 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=105 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=106 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=107 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=108 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=109 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=110 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=111 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=112 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=113 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=114 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=115 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=116 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=117 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=118 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=119 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=120 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=121 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=122 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=123 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=124 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=125 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=126 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=127 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=128 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=129 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=130 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=131 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=132 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=133 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=134 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=135 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=136 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=137 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=138 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=139 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=140 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=141 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=142 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=143 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=144 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=145 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=146 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=147 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=148 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=149 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=150 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=151 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=152 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=153 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=154 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=155 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=156 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=157 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=158 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=159 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=160 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=161 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=162 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=163 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=164 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=165 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=166 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=167 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=168 | ARI=0.9899, NMI=0.9838
# Mental State - Seed=169 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=170 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=171 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=172 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=173 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=174 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=175 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=176 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=177 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=178 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=179 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=180 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=181 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=182 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=183 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=184 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=185 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=186 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=187 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=188 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=189 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=190 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=191 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=192 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=193 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=194 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=195 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=196 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=197 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=198 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=199 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=200 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=201 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=202 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=203 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=204 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=205 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=206 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=207 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=208 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=209 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=210 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=211 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=212 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=213 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=214 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=215 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=216 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=217 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=218 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=219 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=220 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=221 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=222 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=223 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=224 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=225 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=226 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=227 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=228 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=229 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=230 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=231 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=232 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=233 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=234 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=235 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=236 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=237 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=238 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=239 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=240 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=241 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=242 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=243 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=244 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=245 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=246 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=247 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=248 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=249 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=250 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=251 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=252 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=253 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=254 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=255 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=256 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=257 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=258 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=259 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=260 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=261 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=262 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=263 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=264 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=265 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=266 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=267 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=268 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=269 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=270 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=271 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=272 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=273 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=274 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=275 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=276 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=277 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=278 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=279 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=280 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=281 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=282 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=283 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=284 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=285 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=286 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=287 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=288 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=289 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=290 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=291 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=292 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=293 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=294 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=295 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=296 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=297 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=298 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=299 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=300 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=301 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=302 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=303 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=304 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=305 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=306 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=307 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=308 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=309 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=310 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=311 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=312 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=313 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=314 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=315 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=316 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=317 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=318 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=319 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=320 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=321 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=322 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=323 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=324 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=325 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=326 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=327 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=328 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=329 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=330 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=331 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=332 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=333 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=334 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=335 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=336 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=337 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=338 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=339 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=340 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=341 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=342 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=343 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=344 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=345 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=346 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=347 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=348 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=349 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=350 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=351 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=352 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=353 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=354 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=355 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=356 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=357 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=358 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=359 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=360 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=361 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=362 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=363 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=364 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=365 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=366 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=367 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=368 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=369 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=370 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=371 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=372 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=373 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=374 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=375 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=376 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=377 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=378 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=379 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=380 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=381 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=382 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=383 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=384 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=385 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=386 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=387 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=388 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=389 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=390 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=391 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=392 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=393 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=394 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=395 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=396 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=397 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=398 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=399 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=400 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=401 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=402 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=403 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=404 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=405 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=406 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=407 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=408 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=409 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=410 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=411 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=412 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=413 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=414 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=415 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=416 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=417 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=418 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=419 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=420 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=421 | ARI=0.9899, NMI=0.9838
# Mental State - Seed=422 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=423 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=424 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=425 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=426 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=427 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=428 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=429 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=430 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=431 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=432 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=433 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=434 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=435 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=436 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=437 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=438 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=439 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=440 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=441 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=442 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=443 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=444 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=445 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=446 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=447 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=448 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=449 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=450 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=451 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=452 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=453 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=454 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=455 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=456 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=457 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=458 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=459 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=460 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=461 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=462 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=463 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=464 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=465 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=466 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=467 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=468 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=469 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=470 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=471 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=472 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=473 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=474 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=475 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=476 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=477 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=478 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=479 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=480 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=481 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=482 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=483 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=484 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=485 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=486 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=487 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=488 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=489 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=490 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=491 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=492 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=493 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=494 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=495 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=496 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=497 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=498 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=499 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=500 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=501 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=502 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=503 | ARI=1.0000, NMI=1.0000
# Mental State - Seed=504 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=505 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=506 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=507 | ARI=0.9899, NMI=0.9855
# Mental State - Seed=508 | ARI=0.9949, NMI=0.9919
# Mental State - Seed=509 | ARI=1.0000, NMI=1.0000
#
# --- Mental State Cluster Stability Summary ---
# Mean ARI: 0.9952 ± 0.0029
# Mean NMI: 0.9926 ± 0.0042

# %%
# Evaluate clustering stability for History Clusters

true_labels_history = data_cleaned_dropped.loc[history_processed.shape[0]*[True], 'History_Cluster'].values

evaluate_stability(history_processed, true_labels_history, domain_name="History")
# Out:
# History - Seed=10 | ARI=0.8918, NMI=0.8872
# History - Seed=11 | ARI=0.4911, NMI=0.5735
# History - Seed=12 | ARI=0.3763, NMI=0.5126
# History - Seed=13 | ARI=0.3844, NMI=0.4720
# History - Seed=14 | ARI=0.3601, NMI=0.4305
# History - Seed=15 | ARI=0.5425, NMI=0.6364
# History - Seed=16 | ARI=0.3491, NMI=0.4955
# History - Seed=17 | ARI=0.3717, NMI=0.5332
# History - Seed=18 | ARI=0.3615, NMI=0.5088
# History - Seed=19 | ARI=0.3614, NMI=0.4155
# History - Seed=20 | ARI=0.4281, NMI=0.5224
# History - Seed=21 | ARI=0.3577, NMI=0.4973
# History - Seed=22 | ARI=0.5100, NMI=0.5919
# History - Seed=23 | ARI=0.8778, NMI=0.8709
# History - Seed=24 | ARI=0.3875, NMI=0.4629
# History - Seed=25 | ARI=0.4248, NMI=0.5137
# History - Seed=26 | ARI=0.3745, NMI=0.4499
# History - Seed=27 | ARI=0.3745, NMI=0.4499
# History - Seed=28 | ARI=0.3818, NMI=0.4698
# History - Seed=29 | ARI=0.3800, NMI=0.5495
# History - Seed=30 | ARI=0.2726, NMI=0.2759
# History - Seed=31 | ARI=0.5045, NMI=0.5863
# History - Seed=32 | ARI=0.5100, NMI=0.5919
# History - Seed=33 | ARI=0.3662, NMI=0.5337
# History - Seed=34 | ARI=0.3648, NMI=0.5209
# History - Seed=35 | ARI=0.3906, NMI=0.5615
# History - Seed=36 | ARI=0.3923, NMI=0.5405
# History - Seed=37 | ARI=0.3597, NMI=0.4999
# History - Seed=38 | ARI=0.3638, NMI=0.4993
# History - Seed=39 | ARI=0.3578, NMI=0.4980
# History - Seed=40 | ARI=0.3601, NMI=0.4305
# History - Seed=41 | ARI=0.3577, NMI=0.4973
# History - Seed=42 | ARI=1.0000, NMI=1.0000
# History - Seed=43 | ARI=0.2720, NMI=0.3679
# History - Seed=44 | ARI=0.4804, NMI=0.5639
# History - Seed=45 | ARI=0.4292, NMI=0.5230
# History - Seed=46 | ARI=0.3095, NMI=0.3352
# History - Seed=47 | ARI=0.4248, NMI=0.5137
# History - Seed=48 | ARI=0.3805, NMI=0.5207
# History - Seed=49 | ARI=0.4804, NMI=0.5639
# History - Seed=50 | ARI=0.3598, NMI=0.4582
# History - Seed=51 | ARI=0.5085, NMI=0.5906
# History - Seed=52 | ARI=0.3648, NMI=0.5209
# History - Seed=53 | ARI=0.9078, NMI=0.9099
# History - Seed=54 | ARI=0.3603, NMI=0.4838
# History - Seed=55 | ARI=0.4796, NMI=0.5704
# History - Seed=56 | ARI=0.2545, NMI=0.2939
# History - Seed=57 | ARI=0.3648, NMI=0.5209
# History - Seed=58 | ARI=0.3750, NMI=0.5328
# History - Seed=59 | ARI=0.3712, NMI=0.5070
# History - Seed=60 | ARI=0.4024, NMI=0.4801
# History - Seed=61 | ARI=0.5425, NMI=0.6364
# History - Seed=62 | ARI=0.4071, NMI=0.5548
# History - Seed=63 | ARI=0.4024, NMI=0.4801
# History - Seed=64 | ARI=0.3648, NMI=0.5209
# History - Seed=65 | ARI=0.4122, NMI=0.5623
# History - Seed=66 | ARI=0.5100, NMI=0.5919
# History - Seed=67 | ARI=0.4024, NMI=0.4801
# History - Seed=68 | ARI=0.4200, NMI=0.5084
# History - Seed=69 | ARI=0.3763, NMI=0.5126
# History - Seed=70 | ARI=0.3809, NMI=0.4683
# History - Seed=71 | ARI=0.3750, NMI=0.5328
# History - Seed=72 | ARI=0.3638, NMI=0.4993
# History - Seed=73 | ARI=0.4174, NMI=0.5710
# History - Seed=74 | ARI=0.3763, NMI=0.5126
# History - Seed=75 | ARI=0.3750, NMI=0.5328
# History - Seed=76 | ARI=0.4990, NMI=0.5810
# History - Seed=77 | ARI=0.3972, NMI=0.5418
# History - Seed=78 | ARI=0.3934, NMI=0.5533
# History - Seed=79 | ARI=0.3768, NMI=0.5453
# History - Seed=80 | ARI=0.3809, NMI=0.4683
# History - Seed=81 | ARI=0.3662, NMI=0.5337
# History - Seed=82 | ARI=0.4655, NMI=0.5726
# History - Seed=83 | ARI=0.3578, NMI=0.4980
# History - Seed=84 | ARI=0.3577, NMI=0.4285
# History - Seed=85 | ARI=0.4911, NMI=0.5735
# History - Seed=86 | ARI=0.4911, NMI=0.5735
# History - Seed=87 | ARI=0.6281, NMI=0.7292
# History - Seed=88 | ARI=0.5045, NMI=0.5863
# History - Seed=89 | ARI=0.3615, NMI=0.5088
# History - Seed=90 | ARI=0.4240, NMI=0.5177
# History - Seed=91 | ARI=0.4024, NMI=0.4801
# History - Seed=92 | ARI=0.3616, NMI=0.5112
# History - Seed=93 | ARI=0.5425, NMI=0.6364
# History - Seed=94 | ARI=0.4016, NMI=0.4807
# History - Seed=95 | ARI=0.5425, NMI=0.6364
# History - Seed=96 | ARI=0.3875, NMI=0.4629
# History - Seed=97 | ARI=0.3820, NMI=0.4756
# History - Seed=98 | ARI=0.4306, NMI=0.5993
# History - Seed=99 | ARI=0.5045, NMI=0.5863
# History - Seed=100 | ARI=0.3395, NMI=0.4773
# History - Seed=101 | ARI=0.4188, NMI=0.6064
# History - Seed=102 | ARI=0.4796, NMI=0.5704
# History - Seed=103 | ARI=0.9016, NMI=0.9009
# History - Seed=104 | ARI=0.5425, NMI=0.6364
# History - Seed=105 | ARI=0.3653, NMI=0.5173
# History - Seed=106 | ARI=0.4344, NMI=0.5286
# History - Seed=107 | ARI=0.2497, NMI=0.3272
# History - Seed=108 | ARI=0.2568, NMI=0.2847
# History - Seed=109 | ARI=0.3577, NMI=0.4973
# History - Seed=110 | ARI=0.4248, NMI=0.5137
# History - Seed=111 | ARI=0.3614, NMI=0.4155
# History - Seed=112 | ARI=0.5425, NMI=0.6364
# History - Seed=113 | ARI=0.4009, NMI=0.5000
# History - Seed=114 | ARI=0.3614, NMI=0.4155
# History - Seed=115 | ARI=0.5425, NMI=0.6364
# History - Seed=116 | ARI=0.3610, NMI=0.5166
# History - Seed=117 | ARI=0.4090, NMI=0.5864
# History - Seed=118 | ARI=0.3213, NMI=0.4020
# History - Seed=119 | ARI=0.3491, NMI=0.4955
# History - Seed=120 | ARI=0.5425, NMI=0.6364
# History - Seed=121 | ARI=0.4911, NMI=0.5735
# History - Seed=122 | ARI=0.3579, NMI=0.4470
# History - Seed=123 | ARI=0.3934, NMI=0.5533
# History - Seed=124 | ARI=0.4083, NMI=0.4867
# History - Seed=125 | ARI=0.4248, NMI=0.5137
# History - Seed=126 | ARI=0.4911, NMI=0.5735
# History - Seed=127 | ARI=0.4248, NMI=0.5137
# History - Seed=128 | ARI=0.3763, NMI=0.5126
# History - Seed=129 | ARI=0.3638, NMI=0.4993
# History - Seed=130 | ARI=0.5104, NMI=0.6169
# History - Seed=131 | ARI=0.4165, NMI=0.5104
# History - Seed=132 | ARI=0.3577, NMI=0.4285
# History - Seed=133 | ARI=0.3528, NMI=0.4922
# History - Seed=134 | ARI=0.4200, NMI=0.5084
# History - Seed=135 | ARI=0.4292, NMI=0.5230
# History - Seed=136 | ARI=0.2634, NMI=0.3587
# History - Seed=137 | ARI=0.3528, NMI=0.4922
# History - Seed=138 | ARI=0.4911, NMI=0.5735
# History - Seed=139 | ARI=0.6382, NMI=0.7461
# History - Seed=140 | ARI=0.3638, NMI=0.4993
# History - Seed=141 | ARI=0.3796, NMI=0.4549
# History - Seed=142 | ARI=0.3662, NMI=0.5337
# History - Seed=143 | ARI=0.3722, NMI=0.4591
# History - Seed=144 | ARI=0.3562, NMI=0.5009
# History - Seed=145 | ARI=0.4292, NMI=0.5230
# History - Seed=146 | ARI=0.5425, NMI=0.6364
# History - Seed=147 | ARI=0.4281, NMI=0.5224
# History - Seed=148 | ARI=0.4911, NMI=0.5735
# History - Seed=149 | ARI=0.3602, NMI=0.3995
# History - Seed=150 | ARI=0.3763, NMI=0.5126
# History - Seed=151 | ARI=0.4911, NMI=0.5735
# History - Seed=152 | ARI=0.5425, NMI=0.6364
# History - Seed=153 | ARI=0.3556, NMI=0.3869
# History - Seed=154 | ARI=0.5425, NMI=0.6364
# History - Seed=155 | ARI=0.3271, NMI=0.4586
# History - Seed=156 | ARI=0.8668, NMI=0.8597
# History - Seed=157 | ARI=0.5100, NMI=0.5919
# History - Seed=158 | ARI=0.4281, NMI=0.5224
# History - Seed=159 | ARI=0.5100, NMI=0.5919
# History - Seed=160 | ARI=0.4074, NMI=0.4827
# History - Seed=161 | ARI=0.3843, NMI=0.5400
# History - Seed=162 | ARI=0.3556, NMI=0.3869
# History - Seed=163 | ARI=0.3479, NMI=0.4867
# History - Seed=164 | ARI=0.3814, NMI=0.4505
# History - Seed=165 | ARI=0.3722, NMI=0.4591
# History - Seed=166 | ARI=0.8824, NMI=0.8760
# History - Seed=167 | ARI=0.3763, NMI=0.5126
# History - Seed=168 | ARI=0.4990, NMI=0.5810
# History - Seed=169 | ARI=0.5209, NMI=0.6017
# History - Seed=170 | ARI=0.3875, NMI=0.4629
# History - Seed=171 | ARI=0.3638, NMI=0.4993
# History - Seed=172 | ARI=0.4120, NMI=0.5645
# History - Seed=173 | ARI=0.5045, NMI=0.5863
# History - Seed=174 | ARI=0.4200, NMI=0.5084
# History - Seed=175 | ARI=0.3745, NMI=0.4499
# History - Seed=176 | ARI=0.4109, NMI=0.4893
# History - Seed=177 | ARI=0.3615, NMI=0.5088
# History - Seed=178 | ARI=0.2497, NMI=0.3272
# History - Seed=179 | ARI=0.2522, NMI=0.3126
# History - Seed=180 | ARI=0.3750, NMI=0.5328
# History - Seed=181 | ARI=0.5425, NMI=0.6364
# History - Seed=182 | ARI=0.3767, NMI=0.4576
# History - Seed=183 | ARI=0.5100, NMI=0.5919
# History - Seed=184 | ARI=0.5425, NMI=0.6364
# History - Seed=185 | ARI=0.5005, NMI=0.5972
# History - Seed=186 | ARI=0.3972, NMI=0.5418
# History - Seed=187 | ARI=0.3663, NMI=0.5105
# History - Seed=188 | ARI=0.3638, NMI=0.4993
# History - Seed=189 | ARI=0.3843, NMI=0.5400
# History - Seed=190 | ARI=0.3648, NMI=0.4364
# History - Seed=191 | ARI=0.2726, NMI=0.2759
# History - Seed=192 | ARI=0.3750, NMI=0.5328
# History - Seed=193 | ARI=0.8824, NMI=0.8760
# History - Seed=194 | ARI=0.3722, NMI=0.4591
# History - Seed=195 | ARI=0.3629, NMI=0.4169
# History - Seed=196 | ARI=0.3750, NMI=0.5328
# History - Seed=197 | ARI=0.4248, NMI=0.5137
# History - Seed=198 | ARI=0.4292, NMI=0.5230
# History - Seed=199 | ARI=0.5425, NMI=0.6364
# History - Seed=200 | ARI=0.3875, NMI=0.4629
# History - Seed=201 | ARI=0.3717, NMI=0.5332
# History - Seed=202 | ARI=0.5085, NMI=0.5906
# History - Seed=203 | ARI=0.4729, NMI=0.5415
# History - Seed=204 | ARI=0.3638, NMI=0.4993
# History - Seed=205 | ARI=0.4248, NMI=0.5137
# History - Seed=206 | ARI=0.4344, NMI=0.5286
# History - Seed=207 | ARI=0.3756, NMI=0.5290
# History - Seed=208 | ARI=0.4248, NMI=0.5137
# History - Seed=209 | ARI=0.4248, NMI=0.5137
# History - Seed=210 | ARI=0.5100, NMI=0.5919
# History - Seed=211 | ARI=0.3929, NMI=0.4686
# History - Seed=212 | ARI=0.3763, NMI=0.5126
# History - Seed=213 | ARI=0.3598, NMI=0.4582
# History - Seed=214 | ARI=0.4109, NMI=0.4893
# History - Seed=215 | ARI=0.4796, NMI=0.5704
# History - Seed=216 | ARI=0.2497, NMI=0.3272
# History - Seed=217 | ARI=0.4990, NMI=0.5810
# History - Seed=218 | ARI=0.5974, NMI=0.6825
# History - Seed=219 | ARI=0.9099, NMI=0.9022
# History - Seed=220 | ARI=0.4248, NMI=0.5137
# History - Seed=221 | ARI=0.4272, NMI=0.5917
# History - Seed=222 | ARI=0.5425, NMI=0.6364
# History - Seed=223 | ARI=0.5045, NMI=0.5863
# History - Seed=224 | ARI=0.3745, NMI=0.4499
# History - Seed=225 | ARI=0.9041, NMI=0.9049
# History - Seed=226 | ARI=0.3648, NMI=0.4364
# History - Seed=227 | ARI=0.5209, NMI=0.6017
# History - Seed=228 | ARI=0.3750, NMI=0.5328
# History - Seed=229 | ARI=0.3843, NMI=0.5400
# History - Seed=230 | ARI=0.5425, NMI=0.6364
# History - Seed=231 | ARI=0.4911, NMI=0.5735
# History - Seed=232 | ARI=0.3482, NMI=0.4934
# History - Seed=233 | ARI=0.8918, NMI=0.8872
# History - Seed=234 | ARI=0.4729, NMI=0.5415
# History - Seed=235 | ARI=0.3638, NMI=0.4993
# History - Seed=236 | ARI=0.6281, NMI=0.7292
# History - Seed=237 | ARI=0.3577, NMI=0.4285
# History - Seed=238 | ARI=0.4227, NMI=0.5830
# History - Seed=239 | ARI=0.5425, NMI=0.6364
# History - Seed=240 | ARI=0.4292, NMI=0.5230
# History - Seed=241 | ARI=0.6281, NMI=0.7292
# History - Seed=242 | ARI=0.4911, NMI=0.5735
# History - Seed=243 | ARI=0.3016, NMI=0.3086
# History - Seed=244 | ARI=0.4796, NMI=0.5704
# History - Seed=245 | ARI=0.4120, NMI=0.5645
# History - Seed=246 | ARI=0.4083, NMI=0.4867
# History - Seed=247 | ARI=0.3528, NMI=0.4922
# History - Seed=248 | ARI=0.4819, NMI=0.5667
# History - Seed=249 | ARI=0.3651, NMI=0.4420
# History - Seed=250 | ARI=0.5425, NMI=0.6364
# History - Seed=251 | ARI=0.3625, NMI=0.4935
# History - Seed=252 | ARI=0.4024, NMI=0.4801
# History - Seed=253 | ARI=0.3843, NMI=0.5400
# History - Seed=254 | ARI=0.3598, NMI=0.4582
# History - Seed=255 | ARI=0.3407, NMI=0.4789
# History - Seed=256 | ARI=0.4083, NMI=0.4867
# History - Seed=257 | ARI=0.4024, NMI=0.4801
# History - Seed=258 | ARI=0.3667, NMI=0.5244
# History - Seed=259 | ARI=0.2565, NMI=0.3354
# History - Seed=260 | ARI=0.5054, NMI=0.6054
# History - Seed=261 | ARI=0.5425, NMI=0.6364
# History - Seed=262 | ARI=0.4655, NMI=0.5726
# History - Seed=263 | ARI=0.3482, NMI=0.4934
# History - Seed=264 | ARI=0.4024, NMI=0.4801
# History - Seed=265 | ARI=0.5100, NMI=0.5919
# History - Seed=266 | ARI=0.3528, NMI=0.4922
# History - Seed=267 | ARI=0.3426, NMI=0.4770
# History - Seed=268 | ARI=0.3745, NMI=0.4499
# History - Seed=269 | ARI=0.3796, NMI=0.4549
# History - Seed=270 | ARI=0.4200, NMI=0.5084
# History - Seed=271 | ARI=0.3648, NMI=0.4364
# History - Seed=272 | ARI=0.3745, NMI=0.4499
# History - Seed=273 | ARI=0.4796, NMI=0.5704
# History - Seed=274 | ARI=0.4248, NMI=0.5137
# History - Seed=275 | ARI=0.3600, NMI=0.5051
# History - Seed=276 | ARI=0.4796, NMI=0.5704
# History - Seed=277 | ARI=0.4911, NMI=0.5735
# History - Seed=278 | ARI=0.3528, NMI=0.4922
# History - Seed=279 | ARI=0.5974, NMI=0.6825
# History - Seed=280 | ARI=0.3745, NMI=0.4499
# History - Seed=281 | ARI=0.5005, NMI=0.5972
# History - Seed=282 | ARI=0.3822, NMI=0.4575
# History - Seed=283 | ARI=0.3556, NMI=0.3869
# History - Seed=284 | ARI=0.4203, NMI=0.4993
# History - Seed=285 | ARI=0.3662, NMI=0.5337
# History - Seed=286 | ARI=0.3648, NMI=0.4364
# History - Seed=287 | ARI=0.4109, NMI=0.4893
# History - Seed=288 | ARI=0.3745, NMI=0.4499
# History - Seed=289 | ARI=0.4804, NMI=0.5639
# History - Seed=290 | ARI=0.3648, NMI=0.5209
# History - Seed=291 | ARI=0.3560, NMI=0.4452
# History - Seed=292 | ARI=0.4990, NMI=0.5810
# History - Seed=293 | ARI=0.8668, NMI=0.8597
# History - Seed=294 | ARI=0.3929, NMI=0.4686
# History - Seed=295 | ARI=0.4120, NMI=0.5645
# History - Seed=296 | ARI=0.4248, NMI=0.5137
# History - Seed=297 | ARI=0.4281, NMI=0.5224
# History - Seed=298 | ARI=0.4200, NMI=0.5084
# History - Seed=299 | ARI=0.3297, NMI=0.4446
# History - Seed=300 | ARI=0.4024, NMI=0.4801
# History - Seed=301 | ARI=0.3929, NMI=0.4686
# History - Seed=302 | ARI=0.4911, NMI=0.5735
# History - Seed=303 | ARI=0.2925, NMI=0.3978
# History - Seed=304 | ARI=0.3722, NMI=0.4591
# History - Seed=305 | ARI=0.3835, NMI=0.4704
# History - Seed=306 | ARI=0.8778, NMI=0.8709
# History - Seed=307 | ARI=0.3809, NMI=0.4683
# History - Seed=308 | ARI=0.4292, NMI=0.5230
# History - Seed=309 | ARI=0.5425, NMI=0.6364
# History - Seed=310 | ARI=0.3996, NMI=0.5727
# History - Seed=311 | ARI=0.5425, NMI=0.6364
# History - Seed=312 | ARI=0.3906, NMI=0.5615
# History - Seed=313 | ARI=0.3843, NMI=0.5400
# History - Seed=314 | ARI=0.4188, NMI=0.6064
# History - Seed=315 | ARI=0.5974, NMI=0.6825
# History - Seed=316 | ARI=0.3875, NMI=0.4629
# History - Seed=317 | ARI=0.4248, NMI=0.5137
# History - Seed=318 | ARI=0.3756, NMI=0.5290
# History - Seed=319 | ARI=0.3750, NMI=0.5328
# History - Seed=320 | ARI=0.5100, NMI=0.5919
# History - Seed=321 | ARI=0.4024, NMI=0.4801
# History - Seed=322 | ARI=0.8778, NMI=0.8709
# History - Seed=323 | ARI=0.8626, NMI=0.8556
# History - Seed=324 | ARI=0.3760, NMI=0.5452
# History - Seed=325 | ARI=0.3814, NMI=0.4505
# History - Seed=326 | ARI=0.3750, NMI=0.5328
# History - Seed=327 | ARI=0.3750, NMI=0.5328
# History - Seed=328 | ARI=1.0000, NMI=1.0000
# History - Seed=329 | ARI=0.4911, NMI=0.5735
# History - Seed=330 | ARI=0.4911, NMI=0.5735
# History - Seed=331 | ARI=0.3818, NMI=0.4698
# History - Seed=332 | ARI=0.7690, NMI=0.7579
# History - Seed=333 | ARI=0.5425, NMI=0.6364
# History - Seed=334 | ARI=0.7959, NMI=0.7717
# History - Seed=335 | ARI=0.3649, NMI=0.5077
# History - Seed=336 | ARI=0.3875, NMI=0.4629
# History - Seed=337 | ARI=0.3875, NMI=0.4629
# History - Seed=338 | ARI=0.4796, NMI=0.5704
# History - Seed=339 | ARI=0.3750, NMI=0.5328
# History - Seed=340 | ARI=0.3528, NMI=0.4922
# History - Seed=341 | ARI=0.4109, NMI=0.4893
# History - Seed=342 | ARI=0.4911, NMI=0.5735
# History - Seed=343 | ARI=0.4165, NMI=0.5104
# History - Seed=344 | ARI=0.4165, NMI=0.5104
# History - Seed=345 | ARI=0.4248, NMI=0.5137
# History - Seed=346 | ARI=0.2720, NMI=0.3679
# History - Seed=347 | ARI=0.8626, NMI=0.8556
# History - Seed=348 | ARI=0.8668, NMI=0.8597
# History - Seed=349 | ARI=0.3750, NMI=0.5328
# History - Seed=350 | ARI=0.8626, NMI=0.8556
# History - Seed=351 | ARI=0.3614, NMI=0.4155
# History - Seed=352 | ARI=0.3580, NMI=0.4341
# History - Seed=353 | ARI=0.3638, NMI=0.4993
# History - Seed=354 | ARI=0.5054, NMI=0.6054
# History - Seed=355 | ARI=0.3800, NMI=0.5495
# History - Seed=356 | ARI=0.5425, NMI=0.6364
# History - Seed=357 | ARI=0.4911, NMI=0.5735
# History - Seed=358 | ARI=0.5259, NMI=0.6195
# History - Seed=359 | ARI=0.4024, NMI=0.4801
# History - Seed=360 | ARI=0.8626, NMI=0.8556
# History - Seed=361 | ARI=0.8778, NMI=0.8709
# History - Seed=362 | ARI=0.3996, NMI=0.5727
# History - Seed=363 | ARI=0.4281, NMI=0.5224
# History - Seed=364 | ARI=0.5045, NMI=0.5863
# History - Seed=365 | ARI=0.3622, NMI=0.5296
# History - Seed=366 | ARI=0.5209, NMI=0.6017
# History - Seed=367 | ARI=0.3666, NMI=0.5147
# History - Seed=368 | ARI=0.3722, NMI=0.4591
# History - Seed=369 | ARI=0.4024, NMI=0.4801
# History - Seed=370 | ARI=0.4819, NMI=0.5667
# History - Seed=371 | ARI=0.8626, NMI=0.8556
# History - Seed=372 | ARI=0.4024, NMI=0.4801
# History - Seed=373 | ARI=0.3261, NMI=0.4390
# History - Seed=374 | ARI=0.3628, NMI=0.4343
# History - Seed=375 | ARI=0.3663, NMI=0.5105
# History - Seed=376 | ARI=0.3426, NMI=0.4770
# History - Seed=377 | ARI=0.3598, NMI=0.4582
# History - Seed=378 | ARI=0.7341, NMI=0.7688
# History - Seed=379 | ARI=0.3479, NMI=0.4867
# History - Seed=380 | ARI=0.4796, NMI=0.5704
# History - Seed=381 | ARI=0.5104, NMI=0.6169
# History - Seed=382 | ARI=0.3763, NMI=0.5126
# History - Seed=383 | ARI=0.2676, NMI=0.3566
# History - Seed=384 | ARI=0.3756, NMI=0.5290
# History - Seed=385 | ARI=0.3750, NMI=0.5328
# History - Seed=386 | ARI=0.2726, NMI=0.2759
# History - Seed=387 | ARI=0.5425, NMI=0.6364
# History - Seed=388 | ARI=0.7713, NMI=0.7822
# History - Seed=389 | ARI=0.2565, NMI=0.3354
# History - Seed=390 | ARI=0.3713, NMI=0.5224
# History - Seed=391 | ARI=0.5045, NMI=0.5863
# History - Seed=392 | ARI=0.3809, NMI=0.4683
# History - Seed=393 | ARI=0.3638, NMI=0.4993
# History - Seed=394 | ARI=0.4090, NMI=0.5864
# History - Seed=395 | ARI=0.4030, NMI=0.5731
# History - Seed=396 | ARI=0.4990, NMI=0.5810
# History - Seed=397 | ARI=0.4248, NMI=0.5137
# History - Seed=398 | ARI=0.3875, NMI=0.4629
# History - Seed=399 | ARI=0.2676, NMI=0.3566
# History - Seed=400 | ARI=0.7204, NMI=0.7523
# History - Seed=401 | ARI=0.4248, NMI=0.5137
# History - Seed=402 | ARI=0.4990, NMI=0.5810
# History - Seed=403 | ARI=0.3556, NMI=0.3869
# History - Seed=404 | ARI=0.3800, NMI=0.5495
# History - Seed=405 | ARI=0.5425, NMI=0.6364
# History - Seed=406 | ARI=0.5045, NMI=0.5863
# History - Seed=407 | ARI=0.3503, NMI=0.3773
# History - Seed=408 | ARI=0.4114, NMI=0.4932
# History - Seed=409 | ARI=0.4024, NMI=0.4801
# History - Seed=410 | ARI=0.4306, NMI=0.5993
# History - Seed=411 | ARI=0.4306, NMI=0.5993
# History - Seed=412 | ARI=0.4911, NMI=0.5735
# History - Seed=413 | ARI=0.3767, NMI=0.4576
# History - Seed=414 | ARI=0.5085, NMI=0.5906
# History - Seed=415 | ARI=0.4911, NMI=0.5735
# History - Seed=416 | ARI=0.3638, NMI=0.4993
# History - Seed=417 | ARI=0.4024, NMI=0.4801
# History - Seed=418 | ARI=0.3577, NMI=0.4285
# History - Seed=419 | ARI=0.3722, NMI=0.4591
# History - Seed=420 | ARI=0.4911, NMI=0.5735
# History - Seed=421 | ARI=0.4911, NMI=0.5735
# History - Seed=422 | ARI=0.4791, NMI=0.5495
# History - Seed=423 | ARI=0.3763, NMI=0.5126
# History - Seed=424 | ARI=0.4655, NMI=0.5726
# History - Seed=425 | ARI=0.3638, NMI=0.4993
# History - Seed=426 | ARI=0.2676, NMI=0.3566
# History - Seed=427 | ARI=0.4655, NMI=0.5726
# History - Seed=428 | ARI=0.4148, NMI=0.4936
# History - Seed=429 | ARI=0.3717, NMI=0.5332
# History - Seed=430 | ARI=0.3750, NMI=0.5328
# History - Seed=431 | ARI=0.4120, NMI=0.5645
# History - Seed=432 | ARI=0.4109, NMI=0.4893
# History - Seed=433 | ARI=0.3835, NMI=0.4704
# History - Seed=434 | ARI=0.3750, NMI=0.5328
# History - Seed=435 | ARI=0.4911, NMI=0.5735
# History - Seed=436 | ARI=0.3767, NMI=0.4576
# History - Seed=437 | ARI=0.3578, NMI=0.4980
# History - Seed=438 | ARI=0.4729, NMI=0.5415
# History - Seed=439 | ARI=0.3756, NMI=0.5290
# History - Seed=440 | ARI=0.3648, NMI=0.5209
# History - Seed=441 | ARI=0.5425, NMI=0.6364
# History - Seed=442 | ARI=0.4203, NMI=0.4993
# History - Seed=443 | ARI=0.3482, NMI=0.4934
# History - Seed=444 | ARI=0.4083, NMI=0.4867
# History - Seed=445 | ARI=0.2547, NMI=0.3089
# History - Seed=446 | ARI=0.4200, NMI=0.5084
# History - Seed=447 | ARI=0.4030, NMI=0.5731
# History - Seed=448 | ARI=0.3763, NMI=0.5126
# History - Seed=449 | ARI=0.3767, NMI=0.4576
# History - Seed=450 | ARI=0.3662, NMI=0.5337
# History - Seed=451 | ARI=0.4655, NMI=0.5726
# History - Seed=452 | ARI=0.5425, NMI=0.6364
# History - Seed=453 | ARI=0.3763, NMI=0.5126
# History - Seed=454 | ARI=0.3875, NMI=0.4629
# History - Seed=455 | ARI=0.2612, NMI=0.3249
# History - Seed=456 | ARI=0.4911, NMI=0.5735
# History - Seed=457 | ARI=0.3651, NMI=0.4375
# History - Seed=458 | ARI=0.5100, NMI=0.5919
# History - Seed=459 | ARI=0.3597, NMI=0.4999
# History - Seed=460 | ARI=0.4188, NMI=0.6064
# History - Seed=461 | ARI=0.3760, NMI=0.5452
# History - Seed=462 | ARI=0.3875, NMI=0.4629
# History - Seed=463 | ARI=0.4248, NMI=0.5137
# History - Seed=464 | ARI=0.4120, NMI=0.5645
# History - Seed=465 | ARI=0.3503, NMI=0.3773
# History - Seed=466 | ARI=0.3471, NMI=0.4833
# History - Seed=467 | ARI=0.2701, NMI=0.2943
# History - Seed=468 | ARI=0.3610, NMI=0.5166
# History - Seed=469 | ARI=0.3745, NMI=0.4499
# History - Seed=470 | ARI=0.4655, NMI=0.5726
# History - Seed=471 | ARI=0.3747, NMI=0.4609
# History - Seed=472 | ARI=0.4281, NMI=0.5224
# History - Seed=473 | ARI=0.2497, NMI=0.3272
# History - Seed=474 | ARI=0.3615, NMI=0.5088
# History - Seed=475 | ARI=0.4120, NMI=0.5645
# History - Seed=476 | ARI=0.5425, NMI=0.6364
# History - Seed=477 | ARI=0.3750, NMI=0.5328
# History - Seed=478 | ARI=0.4188, NMI=0.6064
# History - Seed=479 | ARI=0.3407, NMI=0.4789
# History - Seed=480 | ARI=0.3610, NMI=0.5166
# History - Seed=481 | ARI=0.3767, NMI=0.4576
# History - Seed=482 | ARI=0.3628, NMI=0.4343
# History - Seed=483 | ARI=0.4911, NMI=0.5735
# History - Seed=484 | ARI=0.3796, NMI=0.4549
# History - Seed=485 | ARI=0.3805, NMI=0.5207
# History - Seed=486 | ARI=0.3547, NMI=0.5037
# History - Seed=487 | ARI=0.3614, NMI=0.4155
# History - Seed=488 | ARI=0.3763, NMI=0.5126
# History - Seed=489 | ARI=0.2676, NMI=0.3566
# History - Seed=490 | ARI=0.4911, NMI=0.5735
# History - Seed=491 | ARI=0.4911, NMI=0.5735
# History - Seed=492 | ARI=0.3482, NMI=0.4934
# History - Seed=493 | ARI=0.5425, NMI=0.6364
# History - Seed=494 | ARI=0.4911, NMI=0.5735
# History - Seed=495 | ARI=0.3809, NMI=0.4683
# History - Seed=496 | ARI=0.3560, NMI=0.4452
# History - Seed=497 | ARI=0.3577, NMI=0.4285
# History - Seed=498 | ARI=0.3577, NMI=0.4973
# History - Seed=499 | ARI=0.4281, NMI=0.5224
# History - Seed=500 | ARI=0.3407, NMI=0.4789
# History - Seed=501 | ARI=0.3491, NMI=0.4955
# History - Seed=502 | ARI=0.3407, NMI=0.4789
# History - Seed=503 | ARI=0.3756, NMI=0.5290
# History - Seed=504 | ARI=0.3615, NMI=0.5088
# History - Seed=505 | ARI=0.5104, NMI=0.6169
# History - Seed=506 | ARI=0.7341, NMI=0.7688
# History - Seed=507 | ARI=0.3929, NMI=0.4686
# History - Seed=508 | ARI=0.4911, NMI=0.5735
# History - Seed=509 | ARI=0.3530, NMI=0.5047
#
# --- History Cluster Stability Summary ---
# Mean ARI: 0.4357 ± 0.1259
# Mean NMI: 0.5349 ± 0.1089

# %%
# Evaluate clustering stability with 80% resampling
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
import matplotlib.pyplot as plt
import seaborn as sns

def evaluate_stability_resample(X, true_labels, domain_name, n_clusters=4, n_runs=500, resample_fraction=0.8):
    ari_scores = []
    nmi_scores = []
    n_samples = X.shape[0]

    for i in range(n_runs):
        # Step 1: Randomly sample 80% of the data
        sample_indices = np.random.choice(n_samples, size=int(resample_fraction*n_samples), replace=False)
        X_sample = X[sample_indices]
        labels_true_sample = true_labels[sample_indices]

        # Step 2: Run K-Means on the subsample
        km = KMeans(n_clusters=n_clusters, random_state=i, n_init=10)
        new_labels = km.fit_predict(X_sample)

        # Step 3: Compute ARI and NMI with the subsample true labels
        ari = adjusted_rand_score(labels_true_sample, new_labels)
        nmi = normalized_mutual_info_score(labels_true_sample, new_labels)

        ari_scores.append(ari)
        nmi_scores.append(nmi)

        if i % 50 == 0:  # optional: print progress every 50 runs
            print(f"{domain_name} - Run {i+1}/{n_runs} | ARI={ari:.4f}, NMI={nmi:.4f}")

    # Summary
    print(f"\n--- {domain_name} Cluster Stability with 80% Resampling ---")
    print(f"Mean ARI: {np.mean(ari_scores):.4f} ± {np.std(ari_scores):.4f}")
    print(f"Mean NMI: {np.mean(nmi_scores):.4f} ± {np.std(nmi_scores):.4f}")

    # Plot stability metrics
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    sns.lineplot(x=range(1, n_runs+1), y=ari_scores, marker='o')
    plt.title(f'{domain_name}: ARI Scores (80% Resample)')
    plt.xlabel('Iteration')
    plt.ylabel('ARI')

    plt.subplot(1, 2, 2)
    sns.lineplot(x=range(1, n_runs+1), y=nmi_scores, marker='o', color='green')
    plt.title(f'{domain_name}: NMI Scores (80% Resample)')
    plt.xlabel('Iteration')
    plt.ylabel('NMI')

    plt.tight_layout()
    plt.show()

# Run for Mental State
evaluate_stability_resample(mental_state_processed, true_labels_mental, domain_name="Mental State", n_clusters=4, n_runs=500, resample_fraction=0.8)
# Out:
# Mental State - Run 1/500 | ARI=0.9936, NMI=0.9901
# Mental State - Run 51/500 | ARI=0.9937, NMI=0.9902
# Mental State - Run 101/500 | ARI=0.9938, NMI=0.9903
# Mental State - Run 151/500 | ARI=0.9937, NMI=0.9903
# Mental State - Run 201/500 | ARI=0.9874, NMI=0.9827
# Mental State - Run 251/500 | ARI=0.9979, NMI=0.9920
# Mental State - Run 301/500 | ARI=0.9917, NMI=0.9821
# Mental State - Run 351/500 | ARI=0.9937, NMI=0.9903
# Mental State - Run 401/500 | ARI=0.9875, NMI=0.9826
# Mental State - Run 451/500 | ARI=0.9937, NMI=0.9904
#
# --- Mental State Cluster Stability with 80% Resampling ---
# Mean ARI: 0.9910 ± 0.0084
# Mean NMI: 0.9865 ± 0.0102

# %%
# Extract true labels for History domain
true_labels_history = data_cleaned_dropped.loc[history_indices, 'History_Cluster'].values

# Run resampling stability evaluation for History Clusters
evaluate_stability_resample(history_processed, true_labels_history,
                            domain_name="History", n_clusters=4, n_runs=500, resample_fraction=0.8)
# Out:
# History - Run 1/500 | ARI=0.5395, NMI=0.6279
# History - Run 51/500 | ARI=0.4206, NMI=0.5056
# History - Run 101/500 | ARI=0.3679, NMI=0.4630
# History - Run 151/500 | ARI=0.3670, NMI=0.4224
# History - Run 201/500 | ARI=0.3826, NMI=0.5540
# History - Run 251/500 | ARI=0.4108, NMI=0.4840
# History - Run 301/500 | ARI=0.3974, NMI=0.4825
# History - Run 351/500 | ARI=0.3672, NMI=0.5105
# History - Run 401/500 | ARI=0.3832, NMI=0.4648
# History - Run 451/500 | ARI=0.3631, NMI=0.5211
#
# --- History Cluster Stability with 80% Resampling ---
# Mean ARI: 0.4468 ± 0.1474
# Mean NMI: 0.5455 ± 0.1257

# %%
# Run UMAP on Mental State
umap_model_mental = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
mental_state_embedding = umap_model_mental.fit_transform(mental_state_processed)

# Create DataFrame for plotting
umap_df_mental = pd.DataFrame({
    'UMAP1': mental_state_embedding[:, 0],
    'UMAP2': mental_state_embedding[:, 1],
    'Cluster': data_cleaned_dropped.loc[mental_indices, 'Mental_State_Cluster'].values
})

# Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=umap_df_mental, x='UMAP1', y='UMAP2', hue='Cluster', palette='Set2', s=60)
plt.title('UMAP Projection of Mental State Clusters')
plt.legend(title='Cluster')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Run UMAP on History
umap_model_history = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
history_embedding = umap_model_history.fit_transform(history_processed)

# Create DataFrame for plotting
umap_df_history = pd.DataFrame({
    'UMAP1': history_embedding[:, 0],
    'UMAP2': history_embedding[:, 1],
    'Cluster': data_cleaned_dropped.loc[history_indices, 'History_Cluster'].values
})

# Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=umap_df_history, x='UMAP1', y='UMAP2', hue='Cluster', palette='Set2', s=60)
plt.title('UMAP Projection of History Clusters')
plt.legend(title='Cluster')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# ### Cluster Correlation

# %%
print("\n--- Exploring Relationships Between Cluster Types ---")
ct_clusters = pd.crosstab(data_cleaned_dropped['Mental_State_Cluster'], data_cleaned_dropped['History_Cluster'])
print("Crosstab of Mental State Clusters vs History Clusters:")
print(ct_clusters)

plt.figure(figsize=(8, 6))
sns.heatmap(ct_clusters, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Relationship between Mental State and History Clusters')
plt.xlabel('History Cluster')
plt.ylabel('Mental State Cluster')
plt.show()

# Example: Relationship of Mental State Cluster with Diagnosis
print("\n--- Relationship of Mental State Cluster with Diagnosis (DIAGN) ---")
ct_mental_diagn = pd.crosstab(data_cleaned_dropped['Mental_State_Cluster'], data_cleaned_dropped['DIAGN'])
print(ct_mental_diagn)

# Example: Relationship of History Cluster with Diagnosis
print("\n--- Relationship of History Cluster with Diagnosis (DIAGN) ---")
ct_history_diagn = pd.crosstab(data_cleaned_dropped['History_Cluster'], data_cleaned_dropped['DIAGN'])
ct_history_diagn
# Out:
# --- Exploring Relationships Between Cluster Types ---
# Crosstab of Mental State Clusters vs History Clusters:
# History_Cluster        0   1    2   3
# Mental_State_Cluster
# 0                     60  99  129  39
# 1                      4  24   61  10
# 2                     43  47   70  18
# 3                     20  12   14  14
# --- Relationship of Mental State Cluster with Diagnosis (DIAGN) ---
# DIAGN                 ACUTE PSYCHOSIS  ALZHEIMERS  ANAEMIA  ANXIETY DISORDER  \
# Mental_State_Cluster
# 0                                   5           1        0                 0
# 1                                   1           0        0                 0
# 2                                   3           0        3                 3
# 3                                   0           0        0                 0
#
# DIAGN                 AUTISM  BEHAVIOURAL DISORDER  \
# Mental_State_Cluster
# 0                          3                     3
# 1                          0                     0
# 2                          0                     0
# 3                          0                     0
#
# DIAGN                 BIPOLAR AFFECTION DISORDER  BIPOLAR DISORDER  BPD  \
# Mental_State_Cluster
# 0                                             11                 1    1
# 1                                              3                 0    0
# 2                                              3                 0    0
# 3                                              0                 0    0
#
# DIAGN                 CATATONIC SCHIZ  ...  SCHIZOAFFECTIVE DISORDER  \
# Mental_State_Cluster                   ...
# 0                                   1  ...                         3
# 1                                   0  ...                         3
# 2                                   1  ...                         2
# 3                                   0  ...                         0
#
# DIAGN                 SCHIZOPHRENIA WITH NEGATIVE SYMPTOMS  \
# Mental_State_Cluster
# 0                                                        1
# 1                                                        0
# 2                                                        0
# 3                                                        0
#
# DIAGN                 SCHIZOTYPAL PERSONALITY DISORDER  SEIZURE DISORDER  \
# Mental_State_Cluster
# 0                                                    0                 2
# 1                                                    2                 0
# 2                                                    1                 2
# 3                                                    0                 0
#
# DIAGN                 SIEZURE  SIMPLE SCHIZ  SIMPLE SCHIZOPHRENIA  \
# Mental_State_Cluster
# 0                           3             0                     9
# 1                           0             0                     2
# 2                           0             1                     6
# 3                           0             0                     2
#
# DIAGN                 SUBSTANCE USE  UNDIFFERENTIATED SCHIZOPHRENIA  \
# Mental_State_Cluster
# 0                                 9                               3
# 1                                 0                               1
# 2                                 1                               0
# 3                                 0                               0
#
# DIAGN                 VASCULAR DISFUNCTION
# Mental_State_Cluster
# 0                                        3
# 1                                        0
# 2                                        0
# 3                                        0
#
# [4 rows x 49 columns]
#
# --- Relationship of History Cluster with Diagnosis (DIAGN) ---
# DIAGN            ACUTE PSYCHOSIS  ALZHEIMERS  ANAEMIA  ANXIETY DISORDER  \
# History_Cluster
# 0                              3           0        0                 3
# 1                              2           0        0                 0
# 2                              3           1        3                 0
# 3                              1           0        0                 0
#
# DIAGN            AUTISM  BEHAVIOURAL DISORDER  BIPOLAR AFFECTION DISORDER  \
# History_Cluster
# 0                     3                     0                           2
# 1                     0                     3                           5
# 2                     0                     0                           4
# 3                     0                     0                           6
#
# DIAGN            BIPOLAR DISORDER  BPD  CATATONIC SCHIZ  ...  \
# History_Cluster                                          ...
# 0                               0    0                0  ...
# 1                               0    0                1  ...
# 2                               1    1                1  ...
# 3                               0    0                0  ...
#
# DIAGN            SCHIZOAFFECTIVE DISORDER  \
# History_Cluster
# 0                                       0
# 1                                       2
# 2                                       5
# 3                                       1
#
# DIAGN            SCHIZOPHRENIA WITH NEGATIVE SYMPTOMS  \
# History_Cluster
# 0                                                   0
# 1                                                   0
# 2                                                   1
# 3                                                   0
#
# DIAGN            SCHIZOTYPAL PERSONALITY DISORDER  SEIZURE DISORDER  SIEZURE  \
# History_Cluster
# 0                                               0                 1        1
# 1                                               0                 2        1
# 2                                               3                 1        0
# 3                                               0                 0        1
#
# DIAGN            SIMPLE SCHIZ  SIMPLE SCHIZOPHRENIA  SUBSTANCE USE  \
# History_Cluster
# 0                           0                     2              7
# 1                           1                     6              1
# 2                           0                     7              1
# 3                           0                     4              1
#
# DIAGN            UNDIFFERENTIATED SCHIZOPHRENIA  VASCULAR DISFUNCTION
# History_Cluster
# 0                                             0                     0
# 1                                             0                     0
# 2                                             4                     3
# 3                                             0                     0
#
# [4 rows x 49 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create crosstab
ct_clusters = pd.crosstab(data_cleaned_dropped['Mental_State_Cluster'],
                          data_cleaned_dropped['History_Cluster'])

# Convert counts to row-wise percentages
ct_clusters_pct = ct_clusters.div(ct_clusters.sum(axis=1), axis=0) * 100
ct_clusters_pct = ct_clusters_pct.round(1)

# Plot heatmap with percentages
plt.figure(figsize=(8, 6))
sns.heatmap(ct_clusters_pct, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label':'Percentage (%)'})
plt.title('Percentage of Patients by Mental State and History Clusters')
plt.xlabel('History Cluster')
plt.ylabel('Mental State Cluster')
plt.tight_layout()
plt.show()

# %%
from scipy.stats import chi2_contingency
from math import sqrt

def chi2_with_cramersv(ct):
    """Run Chi-square test and compute Cramer's V"""
    chi2, p, dof, expected = chi2_contingency(ct)
    n = ct.sum().sum()
    cramers_v = sqrt(chi2 / (n * (min(ct.shape)-1)))
    return chi2, p, dof, cramers_v

# Mental State Cluster vs Diagnosis
ct_mental_diagn = pd.crosstab(data_cleaned_dropped['Mental_State_Cluster'],
                              data_cleaned_dropped['DIAGN'])
chi2_1, p_1, dof_1, v_1 = chi2_with_cramersv(ct_mental_diagn)
print("Mental State Cluster vs Diagnosis")
print(f"Chi-square: {chi2_1:.4f}, df={dof_1}, p={p_1:.4f}, Cramer's V={v_1:.3f}")
print("Significant" if p_1 < 0.05 else "Not significant")

# History Cluster vs Diagnosis
ct_history_diagn = pd.crosstab(data_cleaned_dropped['History_Cluster'],
                               data_cleaned_dropped['DIAGN'])
chi2_2, p_2, dof_2, v_2 = chi2_with_cramersv(ct_history_diagn)
print("\nHistory Cluster vs Diagnosis")
print(f"Chi-square: {chi2_2:.4f}, df={dof_2}, p={p_2:.4f}, Cramer's V={v_2:.3f}")
print("Significant" if p_2 < 0.05 else "Not significant")

# Mental State Cluster vs History Cluster
ct_mental_history = pd.crosstab(data_cleaned_dropped['Mental_State_Cluster'],
                                data_cleaned_dropped['History_Cluster'])
chi2_3, p_3, dof_3, v_3 = chi2_with_cramersv(ct_mental_history)
print("\nMental State Cluster vs History Cluster")
print(f"Chi-square: {chi2_3:.4f}, df={dof_3}, p={p_3:.4f}, Cramer's V={v_3:.3f}")
print("Significant" if p_3 < 0.05 else "Not significant")
# Out:
# Mental State Cluster vs Diagnosis
# Chi-square: 420.0302, df=144, p=0.0000, Cramer's V=0.459
# Significant
#
# History Cluster vs Diagnosis
# Chi-square: 278.7549, df=144, p=0.0000, Cramer's V=0.374
# Significant
#
# Mental State Cluster vs History Cluster
# Chi-square: 45.3252, df=9, p=0.0000, Cramer's V=0.151
# Significant
